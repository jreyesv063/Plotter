# %%
from src.Plotter import Plotter
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# zto_v1:
# zto_v2:
# zto_v4: dImuon IsoMu27  (fue el mejor)
# zto_v6: SingleMuon_only ISOmU27

# %%
# --------------------
# General configs
# --------------------
year = "2017"
samples_folder = f"/eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/{year}"

output_folder = "plots_new_st" #"plots_no_st"
lepton_flavor = "mu"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = True

# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True
distribution_with_obj_level_var = "lepton_met_mass"

stadistical_error_using = "cutflow"  # Se modificará para que lea las tablas con los eventos no pesados: cutflow_raw
normalized_to = "sumw"               # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw"


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = "root_files"

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  systematic_error = systematic_error,
                  distribution_with_obj_level_var = distribution_with_obj_level_var,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                 )
# Out:
# Samples directory set to: /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017
# Output directory set to: plots_new_st
# ROOT files directory set to: root_files
#
#  Loading pkl files for 2017
#
#  Luminosity 41.5 fb$^{-1}$ (2017, 13 TeV)
# Checking PKL files: 100%|██████████| 1436/1436 [05:36<00:00,  4.26file/s]
# ✅ Saved: DYJetsToLL_nlo_M-10to50 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/DYJetsToLL_nlo_M-10to50_merged.pkl
# ✅ Saved: DYJetsToLL_nlo_M-50 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/DYJetsToLL_nlo_M-50_merged.pkl
# ✅ Saved: GluGluHToWWToLNuQQ → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/GluGluHToWWToLNuQQ_merged.pkl
# ✅ Saved: QCD_HT1000to1500 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT1000to1500_merged.pkl
# ✅ Saved: QCD_HT100to200 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT100to200_merged.pkl
# ✅ Saved: QCD_HT1500to2000 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT1500to2000_merged.pkl
# ✅ Saved: QCD_HT2000toInf → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT2000toInf_merged.pkl
# ✅ Saved: QCD_HT200to300 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT200to300_merged.pkl
# ✅ Saved: QCD_HT300to500 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT300to500_merged.pkl
# ✅ Saved: QCD_HT500to700 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT500to700_merged.pkl
# ✅ Saved: QCD_HT50to100 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT50to100_merged.pkl
# ✅ Saved: QCD_HT700to1000 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/QCD_HT700to1000_merged.pkl
# ✅ Saved: ST_s-channel_4f_leptonDecays → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ST_s-channel_4f_leptonDecays_merged.pkl
# ✅ Saved: ST_t-channel_antitop_5f_InclusiveDecays → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ST_t-channel_antitop_5f_InclusiveDecays_merged.pkl
# ✅ Saved: ST_t-channel_top_5f_InclusiveDecays → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ST_t-channel_top_5f_InclusiveDecays_merged.pkl
# ✅ Saved: ST_tW_antitop_5f_inclusiveDecays → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ST_tW_antitop_5f_inclusiveDecays_merged.pkl
# ✅ Saved: ST_tW_top_5f_inclusiveDecays → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ST_tW_top_5f_inclusiveDecays_merged.pkl
# ✅ Saved: SingleMuon → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/SingleMuon_merged.pkl
# ✅ Saved: TTTo2L2Nu → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/TTTo2L2Nu_merged.pkl
# ✅ Saved: TTToHadronic → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/TTToHadronic_merged.pkl
# ✅ Saved: TTToSemiLeptonic → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/TTToSemiLeptonic_merged.pkl
# ✅ Saved: VBFHToWWTo2L2Nu → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/VBFHToWWTo2L2Nu_merged.pkl
# ✅ Saved: VBFHToWWToLNuQQ → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/VBFHToWWToLNuQQ_merged.pkl
# ✅ Saved: WJetsToLNu_HT-100To200 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-100To200_merged.pkl
# ✅ Saved: WJetsToLNu_HT-1200To2500 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-1200To2500_merged.pkl
# ✅ Saved: WJetsToLNu_HT-200To400 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-200To400_merged.pkl
# ✅ Saved: WJetsToLNu_HT-2500ToInf → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-2500ToInf_merged.pkl
# ✅ Saved: WJetsToLNu_HT-400To600 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-400To600_merged.pkl
# ✅ Saved: WJetsToLNu_HT-600To800 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-600To800_merged.pkl
# ✅ Saved: WJetsToLNu_HT-70To100 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-70To100_merged.pkl
# ✅ Saved: WJetsToLNu_HT-800To1200 → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_HT-800To1200_merged.pkl
# ✅ Saved: WJetsToLNu_ext → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_ext_merged.pkl
# ✅ Saved: WJetsToLNu_inclusive → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WJetsToLNu_inclusive_merged.pkl
# ✅ Saved: WW → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WW_merged.pkl
# ✅ Saved: WZ → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/WZ_merged.pkl
# ✅ Saved: ZZ → /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl/ZZ_merged.pkl
#
#
#
# ✅ Saved: DYJetsToLL_nlo_M-10to50 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/DYJetsToLL_nlo_M-10to50_merged.json
# ✅ Saved: DYJetsToLL_nlo_M-50 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/DYJetsToLL_nlo_M-50_merged.json
# ✅ Saved: GluGluHToWWToLNuQQ →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/GluGluHToWWToLNuQQ_merged.json
# ✅ Saved: QCD_HT1000to1500 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT1000to1500_merged.json
# ✅ Saved: QCD_HT100to200 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT100to200_merged.json
# ✅ Saved: QCD_HT1500to2000 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT1500to2000_merged.json
# ✅ Saved: QCD_HT2000toInf →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT2000toInf_merged.json
# ✅ Saved: QCD_HT200to300 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT200to300_merged.json
# ✅ Saved: QCD_HT300to500 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT300to500_merged.json
# ✅ Saved: QCD_HT500to700 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT500to700_merged.json
# ✅ Saved: QCD_HT50to100 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT50to100_merged.json
# ✅ Saved: QCD_HT700to1000 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/QCD_HT700to1000_merged.json
# ✅ Saved: ST_s-channel_4f_leptonDecays →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ST_s-channel_4f_leptonDecays_merged.json
# ✅ Saved: ST_t-channel_antitop_5f_InclusiveDecays →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ST_t-channel_antitop_5f_InclusiveDecays_merged.json
# ✅ Saved: ST_t-channel_top_5f_InclusiveDecays →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ST_t-channel_top_5f_InclusiveDecays_merged.json
# ✅ Saved: ST_tW_antitop_5f_inclusiveDecays →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ST_tW_antitop_5f_inclusiveDecays_merged.json
# ✅ Saved: ST_tW_top_5f_inclusiveDecays →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ST_tW_top_5f_inclusiveDecays_merged.json
# ✅ Saved: SingleMuon →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/SingleMuon_merged.json
# ✅ Saved: TTTo2L2Nu →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/TTTo2L2Nu_merged.json
# ✅ Saved: TTToHadronic →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/TTToHadronic_merged.json
# ✅ Saved: TTToSemiLeptonic →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/TTToSemiLeptonic_merged.json
# ✅ Saved: VBFHToWWTo2L2Nu →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/VBFHToWWTo2L2Nu_merged.json
# ✅ Saved: VBFHToWWToLNuQQ →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/VBFHToWWToLNuQQ_merged.json
# ✅ Saved: WJetsToLNu_HT-100To200 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-100To200_merged.json
# ✅ Saved: WJetsToLNu_HT-1200To2500 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-1200To2500_merged.json
# ✅ Saved: WJetsToLNu_HT-200To400 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-200To400_merged.json
# ✅ Saved: WJetsToLNu_HT-2500ToInf →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-2500ToInf_merged.json
# ✅ Saved: WJetsToLNu_HT-400To600 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-400To600_merged.json
# ✅ Saved: WJetsToLNu_HT-600To800 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-600To800_merged.json
# ✅ Saved: WJetsToLNu_HT-70To100 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-70To100_merged.json
# ✅ Saved: WJetsToLNu_HT-800To1200 →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_HT-800To1200_merged.json
# ✅ Saved: WJetsToLNu_ext →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_ext_merged.json
# ✅ Saved: WJetsToLNu_inclusive →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WJetsToLNu_inclusive_merged.json
# ✅ Saved: WW →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WW_merged.json
# ✅ Saved: WZ →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/WZ_merged.json
# ✅ Saved: ZZ →  /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata/ZZ_merged.json
#  Reading pkl files from: /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/pkl
#  Reading json files from: /eos/user/j/jreyesve/WINDOWS/Desktop/New/z_mu_mu/no_ISR_v3/2017/summary/metadata
#
#  MC estimation normalized to sumw

# %%
table_report = plotter.get_table_report()
table_report
# Out:
# Samples                 Events  Contribution (%)
# DrellYan+jets      29262896.84             99.40
# tt                    97230.71              0.33
# VV                    34468.05              0.12
# QCD                   27323.99              0.09
# SingleTop             10542.41              0.04
# W+jets                 6908.38              0.02
# Higgs                   651.69              0.00
# Data (SingleMuon)  25728716.00               NaN
# Data/Total bgr            0.87               NaN
# Total bgr          29440022.07               NaN

# %%
table_report = plotter.get_table_report()
table_report
# Out:
# Samples                 Events  Contribution (%)
# DrellYan+jets      29251567.43             99.40
# tt                    97291.82              0.33
# VV                    34562.29              0.12
# QCD                   27315.99              0.09
# SingleTop             10549.10              0.04
# W+jets                 6908.69              0.02
# Higgs                   653.28              0.00
# Data (SingleMuon)  26625386.00               NaN
# Data/Total bgr            0.90               NaN
# Total bgr          29428848.59               NaN

# %%
table_report = plotter.get_table_report()
table_report
# Out:
# Samples                 Events  Contribution (%)
# DrellYan+jets      19281823.81             99.83
# VV                    18634.84              0.10
# tt                    10506.02              0.05
# SingleTop              1834.30              0.01
# W+jets                 1105.29              0.01
# Higgs                    83.13              0.00
# QCD                       0.00              0.00
# Data (SingleMuon)  17636598.00               NaN
# Data/Total bgr            0.91               NaN
# Total bgr          19313987.39               NaN

# %% [markdown]
# # Backup

# %%
table_report = plotter.get_table_report()
table_report
# Out:
# Samples                 Events  Contribution (%)
# DrellYan+jets      18793980.98             99.83
# VV                    18071.02              0.10
# tt                    10228.69              0.05
# SingleTop              1777.80              0.01
# W+jets                 1083.92              0.01
# Higgs                    80.58              0.00
# QCD                       0.00              0.00
# Data (SingleMuon)  17636598.00               NaN
# Data/Total bgr            0.94               NaN
# Total bgr          18825222.99               NaN

# %%
table_report = plotter.get_table_report()
table_report
# Out:
# Samples                 Events  Contribution (%)
# DrellYan+jets      18794058.76             99.83
# VV                    18071.02              0.10
# tt                    10228.76              0.05
# SingleTop              1777.80              0.01
# W+jets                 1082.63              0.01
# Higgs                    80.58              0.00
# QCD                       0.00              0.00
# Data (SingleMuon)  17235622.00               NaN
# Data/Total bgr            0.92               NaN
# Total bgr          18825299.54               NaN

# %%
variable = "mll"
binning = [80, 82, 84, 86, 88, 90, 92, 94, 96, 98, 100, 102, 104, 106, 108, 110] 
overflow = True
underflow = True

divided_GeV = True
log_scale = False

main_bgr = "tt"
sf_bgr = 1.0

#y_axis_range = (0.1, 4000000)
y_axis_range = (0.1, 5000000)
ratio_plot_limits = (0.5, 1.5)

# %%
histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['ptl1', 'ptl2', 'ptll', 'mll', 'njets', 'met', 'genweight']
# [WARNING] No valid samples found for group 'qcd'
# Plot saved to plots/mll_2017.pdf

# %%
variable = "ptl1"
binning = [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 350, 400, 450, 500]

# %%
histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['ptl1', 'ptl2', 'ptll', 'mll', 'njets', 'met', 'genweight', 'dimuon_trigger_2017']
# [WARNING] No valid samples found for group 'qcd'
# /eos/home-i01/j/jreyesve/WINDOWS/Desktop/Plotter/src/utils_plot.py:600: RuntimeWarning: invalid value encountered in divide
#   ratio = np.divide(data, total_mc)
# /eos/home-i01/j/jreyesve/WINDOWS/Desktop/Plotter/src/utils_plot.py:603: RuntimeWarning: invalid value encountered in divide
#   error_mc_down_ratio = (total_mc -  total_bgr_error_down)/total_mc
# /eos/home-i01/j/jreyesve/WINDOWS/Desktop/Plotter/src/utils_plot.py:604: RuntimeWarning: invalid value encountered in divide
#   error_mc_up_ratio = (total_bgr_error_up - total_mc)/total_mc
# /eos/home-i01/j/jreyesve/WINDOWS/Desktop/Plotter/src/utils_plot.py:607: RuntimeWarning: invalid value encountered in divide
#   error_data_down = np.sqrt(data)/data
# /eos/home-i01/j/jreyesve/WINDOWS/Desktop/Plotter/src/utils_plot.py:608: RuntimeWarning: invalid value encountered in divide
#   error_data_up = np.sqrt(data)/data
# Plot saved to plots/ptl1_2017.pdf

# %%
from src.Plotter import Plotter
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# --------------------
# General configs
# --------------------
year = "2018"
bgr = "tt"
samples_folder_den = f"/eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_{bgr}/{year}/den"
samples_folder_num = f"/eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_{bgr}/{year}/num"
output_folder = f"plots/eff_{bgr}/{year}"
lepton_flavor = "mu"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False

# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True

stadistical_error_using = "cutflow"  # Se modificará para que lea las tablas con los eventos no pesados: cutflow_raw
normalized_to = "sumw"               # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw"


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# --------------------------
#   Is signal region=
# --------------------------
is_signal = False
signal_superposition = False

# %%
plotter_den = Plotter(year = year, 
                  samples_folder = samples_folder_den,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                  is_SR = is_signal,
                  signal_superposition = signal_superposition,
                 )
# Out:
# Samples directory set to: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/den
# Output directory set to: plots/eff_tt/2018
# ROOT files directory set to: plots/eff_tt/2018/root
#  Reading pkl files from: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/den/summary/pkl
#  Reading json files from: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/den/summary/metadata
#
#  MC estimation normalized to sumw

# %%
plotter_num = Plotter(year = year, 
                  samples_folder = samples_folder_num,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                  is_SR = is_signal,
                  signal_superposition = signal_superposition,
                 )
# Out:
# Samples directory set to: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/num
# Output directory set to: plots/eff_tt/2018
# ROOT files directory set to: plots/eff_tt/2018/root
#  Reading pkl files from: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/num/summary/pkl
#  Reading json files from: /eos/user/j/jreyesve/WINDOWS/Desktop/2025/July/eff_tt/2018/num/summary/metadata
#
#  MC estimation normalized to sumw

# %%
table_report_den = plotter_den.get_table_report()
table_report_den
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down']
#
# 🔎 Revisando dataset tipo data: SingleMuon
# Samples                   Events ± stat  Contribution (%)
# tt                   493995.13 ± 247.69             76.18
# W+jets                69367.21 ± 795.99             10.70
# SingleTop             40906.31 ± 109.68              6.31
# QCD                 35600.65 ± 16374.46              5.49
# DrellYan+jets          7282.70 ± 180.69              1.12
# VV                      1039.94 ± 17.36              0.16
# Higgs                    248.89 ± 28.80              0.04
# Data (SingleMuon)             568030.00               NaN
# Data/Total bgr                     0.88               NaN
# Total bgr          648440.83 ± 16397.06               NaN

# %%
table_report_num = plotter_num.get_table_report()
table_report_num
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down']
#
# 🔎 Revisando dataset tipo data: SingleMuon
# Samples                 Events ± stat  Contribution (%)
# tt                 173357.14 ± 148.04             83.89
# W+jets              16026.81 ± 105.46              7.76
# SingleTop            15020.66 ± 68.81              7.27
# DrellYan+jets         1058.37 ± 58.23              0.51
# QCD                   855.08 ± 300.55              0.41
# VV                      294.83 ± 9.22              0.14
# Higgs                    40.68 ± 9.65              0.02
# Data (SingleMuon)           147438.00               NaN
# Data/Total bgr                   0.71               NaN
# Total bgr          206653.57 ± 362.87               NaN

# %%
variable = "recoil_pt" 
binning = [0, 50, 60, 80, 100, 120, 140, 160, 180, 200, 250, 300, 350, 400,  600]
overflow = True
underflow = True

divided_GeV = True
log_scale = True


sf_bgr = 1.0

y_axis_range = (0.1, 1000000)
ratio_plot_limits = (0.5, 1.5)

histos_den, group_den = plotter_den.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter_den.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'njets_full', 'njets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'HT', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight']
# Plot saved to plots/eff_tt/2018/recoil_pt_2018.pdf
#             $t\bar{t}$  Single Top  WJetToLNu  Diboson  DYJetsToLNu  Higgs  \
# [0, 50)       26662.21     2382.28    9705.14   100.14       899.11  19.07
# [50, 60)      13409.43     1172.08    3817.79    39.54       293.94  10.44
# [60, 80)      34359.53     2921.25    7718.52   101.54       549.80  24.13
# [80, 100)     49554.26     4121.27    8346.58   125.83       982.28  37.40
# [100, 120)    64465.09     5196.38    8613.92   126.53      1356.40  39.05
# [120, 140)    66290.81     5119.04    7570.10   129.96      1165.07  42.06
# [140, 160)    58659.18     4454.26    5668.78   103.74       607.28  20.56
# [160, 180)    47457.39     3589.17    4338.72    74.66       412.47  20.61
# [180, 200)    36291.86     2826.98    3291.36    61.26       325.14  16.60
# [200, 250)    53621.28     4393.00    5112.39    85.80       324.36  15.24
# [250, 300)    23553.38     2173.94    2471.83    43.14       186.46   2.18
# [300, 350)    10379.69     1123.10    1171.11    17.52       118.08   0.78
# [350, 400)     4633.66      594.21     645.44    11.24        21.48   0.42
# [400, 600)     4657.23      839.43     895.48    19.05        40.84   0.35
# Total        493994.94    40906.38   69367.16  1039.94      7282.70 248.89
#
#                 QCD      Data  Total MC  Data / Total MC
# [0, 50)    17732.76  39135.00  57500.70             0.68
# [50, 60)       0.00  19033.00  18743.22             1.02
# [60, 80)     323.51  45280.00  45998.28             0.98
# [80, 100)    683.87  63456.00  63851.47             0.99
# [100, 120)  7494.05  78144.00  87291.42             0.90
# [120, 140)  6017.49  74145.00  86334.54             0.86
# [140, 160)   565.18  62180.00  70078.98             0.89
# [160, 180)   786.55  48946.00  56679.57             0.86
# [180, 200)  1523.73  36900.00  44336.93             0.83
# [200, 250)   323.53  54717.00  63875.59             0.86
# [250, 300)    56.96  24281.00  28487.89             0.85
# [300, 350)    56.79  10894.00  12867.07             0.85
# [350, 400)    14.30   5203.00   5920.75             0.88
# [400, 600)    21.93   5716.00   6474.32             0.88
# Total      35600.64 568030.00 648440.69             0.88

# %%
variable = "recoil_pt" 
binning = [0, 50, 60, 80, 100, 120, 140, 160, 180, 200, 250, 300, 350, 400,  600]
overflow = True
underflow = True

divided_GeV = True
log_scale = True


sf_bgr = 1.0

y_axis_range = (0.1, 1000000)
ratio_plot_limits = (0.5, 1.5)

histos_num, group_num = plotter_num.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter_num.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'njets_full', 'njets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'HT', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight']
# Plot saved to plots/eff_tt/2018/recoil_pt_2018.pdf
#             $t\bar{t}$  Single Top  WJetToLNu  Diboson  DYJetsToLNu  Higgs  \
# [0, 50)         212.55       29.19      31.44     0.00         4.11   0.04
# [50, 60)         96.54        8.34      12.63     0.00       -10.70   0.00
# [60, 80)        339.09       25.78      25.83     1.59         8.52   0.00
# [80, 100)       994.97       69.56      55.70     1.64         8.60   0.07
# [100, 120)     3643.84      254.59     253.95     3.38        29.01   4.11
# [120, 140)    10595.72      765.92     716.32    16.77       111.07   5.92
# [140, 160)    20260.95     1531.43    1550.52    29.78       107.62   5.58
# [160, 180)    26011.96     1999.12    2050.87    38.88       156.89   3.69
# [180, 200)    25625.33     2016.90    2150.27    42.95       131.92   2.87
# [200, 250)    45072.84     3781.16    4240.08    72.75       207.69  14.78
# [250, 300)    21767.35     2052.55    2333.56    41.07       153.72   2.10
# [300, 350)     9878.53     1084.60    1136.92    17.23        89.87   0.78
# [350, 400)     4462.54      579.06     625.91    10.89        13.90   0.42
# [400, 600)     4394.95      822.49     842.78    17.88        46.16   0.32
# Total        173357.19    15020.68   16026.79   294.83      1058.37  40.68
#
#               QCD      Data  Total MC  Data / Total MC
# [0, 50)      0.00    220.00    277.34             0.79
# [50, 60)     0.00    114.00    106.81             1.07
# [60, 80)     0.00    238.00    400.82             0.59
# [80, 100)    0.21    593.00   1130.75             0.52
# [100, 120)   0.00   1796.00   4188.89             0.43
# [120, 140)   0.00   5603.00  12211.72             0.46
# [140, 160)  28.73  12524.00  23514.60             0.53
# [160, 180) 127.43  19246.00  30388.85             0.63
# [180, 200) 353.26  21822.00  30323.49             0.72
# [200, 250) 234.80  43026.00  53624.11             0.80
# [250, 300)  23.80  21895.00  26374.15             0.83
# [300, 350)  50.63  10211.00  12258.56             0.83
# [350, 400)  14.30   4922.00   5707.02             0.86
# [400, 600)  21.93   5228.00   6146.50             0.85
# Total      855.08 147438.00 206653.62             0.71

# %% [markdown]
# # Efficiency
#
# ## Efficiency formulas:
#
# $ \varepsilon = \frac{num}{den} $
#
# $\sigma(\varepsilon) = \varepsilon \times \left[ \left(\frac{\sigma_{num}}{num}\right)^2 + \left(\frac{\sigma_{den}}{den}\right)^2  \right]$
#
# ## Fit:
#
# * Root: https://root.cern.ch/root/html524/TMath.html#TMath:Freq
#
#
# * Python: https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.erf.html#scipy.special.erf
#
#
# What is the equivalence between both expressions?
#
# $\int_{-\infty}^{x} e^{-t^2} dt = \int_{-\infty}^{0} e^{-t^2} dt + \int_{0}^{x} e^{-t^2} dt =  \frac{1}{2}  \int_{-\infty}^{\infty} e^{-t^2} dt + \int_{0}^{x} e^{-t^2} dt =  \frac{\sqrt{\pi}}{2} + \frac{\sqrt{\pi}}{2} erf(x) = \frac{\sqrt{\pi}}{2}\left[1 + erf(x)\right]$
#
#
# Profesor's formula:
#
# $ f(x) = P_{0} +  \frac{P_{1}}{\sqrt{2\pi}} \int_{-\infty}^{\frac{\sqrt{x}- \sqrt{P_{2}}}{2P_{3}}} e^{-\frac{t^2}{2}} = P_{0} + \frac{P_{1}}{\sqrt{2\pi}}\frac{\sqrt{\pi}}{2}\left[1 + erf\left(\frac{\sqrt{x}- \sqrt{P_{2}}}{2P_{3}}\right)\right] = a + b \left[1 + erf\left(\frac{\sqrt{x}- c}{d}\right)\right]   $
#
# Parameters: {a,b,c,d}
#
#
# - a: Constant.
# - b: Amplitude.
# - c: mean value $<x>$.
# - d: standard deviation $\sigma$.
#
# ##### Calculating its derivatives: https://www.youtube.com/watch?v=Jmn8gx3eziI.
#
# * Remember:
#   $\frac{d}{dx} \int_{0}^{g(x)} f(t) dt = \frac{d}{dx} [F(g(x)) - F(0)] = \frac{dF(g(x))}{dx} =  f(g(x))\times\frac{dg(x)}{dx}$
#
# $\frac{\partial f}{\partial a} = 1 $
#
# $\frac{\partial f}{\partial b} = \frac{f - a}{b} $
#
# $\frac{\partial f}{\partial c} = -\frac{2b}{d\sqrt{\pi}}e^{-\left(\frac{\sqrt{x}-c}{d}\right)^2}$
#
# $\frac{\partial f}{\partial d} =  -\frac{2b(\sqrt{x} - c)}{d^2\sqrt{\pi}} e^{-\left(\frac{\sqrt{x}-c}{d}\right)^2} $
#
#
#
#
# ## Variance
#
# $f(x) =  f(a,b,c,d)$
#
# $\sigma_{f} = \sqrt{ \left(\frac{\partial f}{\partial a}\sigma_{a}\right)^2 + \left(\frac{\partial f}{\partial b}\sigma_{b}\right)^2 +  \left(\frac{\partial f}{\partial c}\sigma_{c}\right)^2 +  \left(\frac{\partial f}{\partial d}\sigma_{d}\right)^2 + 2\left[\frac{\partial f}{\partial a} \frac{\partial f}{\partial b}Cov(a,b) + \frac{\partial f}{\partial a} \frac{\partial f}{\partial c}Cov(a,c) + \frac{\partial f}{\partial a}\frac{\partial f}{\partial d}Cov(a,d)  +  \frac{\partial f}{\partial b} \frac{\partial f}{\partial c}Cov(b,c) +  \frac{\partial f}{\partial b} \frac{\partial f}{\partial d}Cov(b,d) +  \frac{\partial f}{\partial c} \frac{\partial f}{\partial d}Cov(c,d) \right]}$
#
#
# We can use the matrix form of the covariance matrix:
#
# $ \Sigma = \begin{pmatrix}\sigma _a^2&Cov\left(a,b\right)&Cov\left(a,c\right)&Cov\left(a,d\right)\\ Cov\left(a,b\right)&\sigma _b^2&Cov\left(b,c\right)&Cov\left(b,d\right)\\ Cov\left(a,c\right)&Cov\left(b,c\right)&\sigma _c^2&Cov\left(c,d\right)\\ Cov\left(a,d\right)&Cov\left(b,d\right)&Cov\left(c,d\right)&\sigma _c^2\end{pmatrix} $
#
# $ df = \begin{pmatrix}\frac{\partial f}{\partial a}\\ \frac{\partial \:f}{\partial b}\\ \frac{\partial f}{\partial c}\\ \frac{\partial f}{\partial d}\end{pmatrix} $
#
# Con lo anterior:
#
# $\sigma_{f}^{2} = df^{T} \times \Sigma \times df $

# %%
from src.utils_efficiency import run_efficiency_curve_plot

run_efficiency_curve_plot(
    group_num=group_num,
    group_den=group_den,
    binning=[0, 50, 60, 80, 100, 120, 140, 160, 180, 200, 250, 300, 350, 400,  600],
    main_back=bgr,
    year=year,
    distribution="recoil_pt",
    trigger_name="HLT_PFMETNoMu120_PFMHTNoMu120_IDTight"
)
# Out:
#     bin_center  eff_data  eff_main  eff_total_mc  weight
# 0        25.00      0.01      0.01          0.01    2.35
# 1        55.00      0.01      0.01          0.01    1.05
# 2        70.00      0.01      0.01          0.01    0.53
# 3        90.00      0.01      0.02          0.02    0.46
# 4       110.00      0.02      0.06          0.05    0.40
# 5       130.00      0.08      0.16          0.14    0.46
# 6       150.00      0.20      0.34          0.34    0.53
# 7       170.00      0.39      0.55          0.54    0.68
# 8       190.00      0.59      0.71          0.68    0.84
# 9       225.00      0.79      0.84          0.84    0.92
# 10      275.00      0.90      0.92          0.93    0.97
# 11      325.00      0.94      0.95          0.95    0.98
# 12      375.00      0.95      0.96          0.96    0.97
# 13      500.00      0.92      0.94          0.95    0.94

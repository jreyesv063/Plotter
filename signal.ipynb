# %%
import numpy as np
from src.Plotter import Plotter

# %%
# --------------------
# General configs
# --------------------
year = "2017"
samples_folder = f"../New_results/signal/{year}" 
output_folder = f"plots/signal/{year}"
lepton_flavor = "tau"
control_region = "signal"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False


# ---------------------
# Include signal samples
# --------------------
include_signal_samples = True


# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True

stadistical_error_using = "cutflow_raw" #  Cutflow_raw: Eventos sin pesar.
normalized_to = "sumw_case_3"                  # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw; sumw_case_1; sumw_case_1; sumw_case_3


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# -------------------------
#    QCD estimation
# -------------------------
activate_qcd_data_driven = True
cr_B_folder = f"../New_results//qcd_hadronic/cr_b/{year}"
cr_C_folder = f"../New_results//qcd_hadronic/cr_c/{year}"
cr_D_folder =  f"../New_results//qcd_hadronic/cr_d/{year}"

qcd_ratio_integrated = False # True si se quiere calcular el transfer factor con los valores integrados
qcd_shape = "cr_b"
qcd_ratio = ["cr_c", "cr_d"] # [Num, Den]

# -------------------------
#    Signal region
# -------------------------
is_signal = True
signal_superposition = True

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  control_region = control_region,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  include_signal_samples = include_signal_samples,                  

                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                  applied_data_driven = activate_qcd_data_driven,
                  cr_B_folder = cr_B_folder,
                  cr_C_folder = cr_C_folder,
                  cr_D_folder = cr_D_folder,

                  is_SR = is_signal,
                  signal_superposition = signal_superposition,

                  qcd_shape = qcd_shape,
                  qcd_ratio = qcd_ratio,   # cr_c/cr_d
                  qcd_ratio_integrated = qcd_ratio_integrated                  
                 )
# Out:
# Samples directory set to: ../New_results/signal/2017
# Output directory set to: plots/signal/2017
# ROOT files directory set to: plots/signal/2017/root
#  Reading pkl files from: ../New_results/signal/2017/summary/pkl
#  Reading json files from: ../New_results/signal/2017/summary/metadata
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3

# %% [markdown]
# # Cutflow

# %%
cutflow_table, error, qcd = plotter.get_table_cutflow(variation = "cutflow", combined_samples = True)
cutflow_table
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#                                               tt           SingleTop  \
# sumw                                 34427415.05         12460301.64
# goodvertex                    34427415.04 ± 0.12  12460301.42 ± 0.59
# lumi                          34427415.04 ± 0.12  12460301.42 ± 0.59
# Stitching                     34427415.04 ± 0.12  12460301.42 ± 0.59
# trigger_tau                  2063490.12 ± 346.96  316076.96 ± 281.47
# metfilters                   2060225.87 ± 346.65  315430.17 ± 281.16
# electron_veto                1716142.04 ± 320.99  268785.89 ± 257.96
# muon_veto                     921453.69 ± 242.74  143808.53 ± 183.23
# one_tau                         55363.65 ± 62.96     8499.71 ± 53.64
# one_bjet                        27460.18 ± 44.41     4103.16 ± 37.81
# delta_phi_jet_met_0.7_False     22077.70 ± 39.80     3527.76 ± 34.90
# met_180                          8120.40 ± 25.10     1492.89 ± 23.35
# failing_top_tagger               5099.16 ± 19.85     1102.75 ± 19.41
#
#                                                W+jets                  VV  \
# sumw                                    2692805841.45          4799650.80
# goodvertex                     2692804206.84 ± 207.32   4799650.65 ± 0.45
# lumi                           2692804206.84 ± 207.32   4799650.65 ± 0.45
# Stitching                    2563617959.95 ± 47585.83   4799650.65 ± 0.45
# trigger_tau                      7925652.64 ± 3888.77  100300.28 ± 148.80
# metfilters                       7915423.96 ± 3886.01  100122.22 ± 148.65
# electron_veto                    7101917.17 ± 3578.26   87017.08 ± 138.19
# muon_veto                        4211016.75 ± 3128.38   55596.18 ± 110.03
# one_tau                            168708.39 ± 497.54     2337.06 ± 24.43
# one_bjet                              3687.52 ± 52.83        78.67 ± 4.44
# delta_phi_jet_met_0.7_False           3160.29 ± 49.99        68.04 ± 4.14
# met_180                               1450.60 ± 31.43        34.66 ± 3.01
# failing_top_tagger                    1261.15 ± 29.22        30.77 ± 2.82
#
#                                       DrellYan+jets              Higgs  \
# sumw                                  1116392720.00         1520283.48
# goodvertex                   1116390646.41 ± 208.11  1520283.44 ± 5.58
# lumi                         1116390646.41 ± 208.11  1520283.44 ± 5.58
# Stitching                    1116390646.41 ± 208.11  1520283.44 ± 5.58
# trigger_tau                     723793.99 ± 2582.44  25901.21 ± 194.68
# metfilters                      721811.49 ± 2578.61  25860.00 ± 194.42
# electron_veto                   697967.90 ± 2534.62  21483.64 ± 187.14
# muon_veto                       172222.54 ± 1391.01  11768.15 ± 153.90
# one_tau                           11683.81 ± 320.76     466.80 ± 25.16
# one_bjet                             506.72 ± 71.62      25.45 ± 10.86
# delta_phi_jet_met_0.7_False          386.23 ± 63.26       20.21 ± 9.72
# met_180                              136.06 ± 32.49        5.35 ± 3.54
# failing_top_tagger                   110.28 ± 30.37        5.19 ± 3.53
#
#                              SignalTau_1000GeV  SignalTau_1500GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.07    41480.00 ± 1.07
# lumi                           41480.00 ± 1.07    41480.00 ± 1.07
# Stitching                      41480.00 ± 1.07    41480.00 ± 1.07
# trigger_tau                   26977.28 ± 99.66   28382.45 ± 97.13
# metfilters                    26903.74 ± 99.77   28256.57 ± 97.38
# electron_veto                23551.63 ± 103.58  24745.66 ± 102.59
# muon_veto                    21234.37 ± 104.51  22071.40 ± 104.34
# one_tau                        9377.09 ± 88.11    9764.71 ± 89.28
# one_bjet                       4219.45 ± 64.50    4311.19 ± 65.04
# delta_phi_jet_met_0.7_False    3634.49 ± 60.26    3637.17 ± 60.21
# met_180                        3088.60 ± 55.90    3272.21 ± 57.34
# failing_top_tagger             2928.39 ± 54.48    3081.58 ± 55.71
#
#                              SignalTau_2000GeV  SignalTau_3000GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.07    41480.00 ± 1.08
# lumi                           41480.00 ± 1.07    41480.00 ± 1.08
# Stitching                      41480.00 ± 1.07    41480.00 ± 1.08
# trigger_tau                   27557.97 ± 98.65  22427.57 ± 104.35
# metfilters                    27406.94 ± 98.91  22307.51 ± 104.41
# electron_veto                23849.47 ± 103.36  19577.98 ± 104.65
# muon_veto                    21030.35 ± 104.56  17280.05 ± 103.43
# one_tau                        8947.74 ± 86.67    7142.75 ± 79.99
# one_bjet                       3951.69 ± 62.56    3125.90 ± 56.60
# delta_phi_jet_met_0.7_False    3318.40 ± 57.81    2595.52 ± 51.92
# met_180                        2988.58 ± 55.03    2265.68 ± 48.57
# failing_top_tagger             2801.11 ± 53.33    2137.31 ± 47.16
#
#                             SignalTau_300GeV  SignalTau_400GeV  \
# sumw                                     NaN               NaN
# goodvertex                   41480.00 ± 1.08   41480.00 ± 1.08
# lumi                         41480.00 ± 1.08   41480.00 ± 1.08
# Stitching                    41480.00 ± 1.08   41480.00 ± 1.08
# trigger_tau                  8417.10 ± 84.69  13763.57 ± 99.10
# metfilters                   8410.22 ± 84.66  13752.15 ± 99.08
# electron_veto                7556.99 ± 81.24  12238.56 ± 95.99
# muon_veto                    6777.56 ± 77.87  11099.03 ± 93.24
# one_tau                      2144.31 ± 48.33   4042.01 ± 64.04
# one_bjet                     1015.43 ± 34.21   1789.75 ± 44.61
# delta_phi_jet_met_0.7_False   935.29 ± 32.85   1620.48 ± 42.51
# met_180                       392.61 ± 21.41    830.64 ± 30.78
# failing_top_tagger            363.58 ± 20.59    773.13 ± 29.64
#
#                               SignalTau_600GeV   SignalTau_750GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.08    41480.00 ± 1.08
# lumi                           41480.00 ± 1.08    41480.00 ± 1.08
# Stitching                      41480.00 ± 1.08    41480.00 ± 1.08
# trigger_tau                  21078.64 ± 104.76  23957.97 ± 103.32
# metfilters                   21038.45 ± 104.76  23909.60 ± 103.36
# electron_veto                18592.26 ± 104.21  21091.24 ± 104.61
# muon_veto                    16924.81 ± 102.99  19133.14 ± 104.32
# one_tau                        6884.84 ± 78.99    8150.25 ± 83.92
# one_bjet                       3100.38 ± 56.71    3602.86 ± 60.38
# delta_phi_jet_met_0.7_False    2755.99 ± 53.68    3153.68 ± 56.81
# met_180                        1941.58 ± 45.41    2458.50 ± 50.54
# failing_top_tagger             1829.67 ± 44.05    2308.59 ± 48.98
#
#                                                 Total
# sumw                                    3862406212.43
# goodvertex                     3862734343.79 ± 293.82
# lumi                           3862734343.79 ± 293.82
# Stitching                    3733548096.90 ± 47586.28
# trigger_tau                     11327777.75 ± 4704.23
# metfilters                      11310858.89 ± 4699.81
# electron_veto                   10044517.51 ± 4419.56
# muon_veto                        5651416.55 ± 3453.94
# one_tau                            303513.12 ± 638.64
# one_bjet                            60978.33 ± 192.33
# delta_phi_jet_met_0.7_False         50891.26 ± 178.05
# met_180                             28478.35 ± 145.13
# failing_top_tagger                  23832.65 ± 139.11

# %%
qcd
# Out:
#                                              QCD cr_b  \
# Cut
# sumw
# goodvertex                  -3435777507.66 ± 20656.99
# lumi                        -3453768427.66 ± 20216.84
# Stitching                   -3324582099.25 ± 51701.92
# trigger_tau                   211947490.20 ± 15657.39
# metfilters                    207314684.00 ± 15506.87
# electron_veto                 207553659.24 ± 15391.52
# muon_veto                     208255417.91 ± 15020.70
# one_tau                             98897.25 ± 839.32
# one_bjet                            -1967.53 ± 212.97
# delta_phi_jet_met_0.7_True             189.24 ± 95.19
# met_180                                526.09 ± 59.72
# failing_top_tagger                     322.36 ± 44.29
#
#                                              QCD cr_c  \
# Cut
# sumw
# goodvertex                  -3435777644.56 ± 20656.99
# lumi                        -3453768564.56 ± 20216.83
# Stitching                   -3324291700.98 ± 51606.52
# trigger_tau                   211960936.39 ± 15651.98
# metfilters                    207328104.64 ± 15501.42
# electron_veto                 207561766.37 ± 15386.54
# muon_veto                     208244180.65 ± 15018.03
# one_tau                            318500.46 ± 735.61
# one_bjet                            10492.90 ± 177.52
# delta_phi_jet_met_0.7_True           7469.99 ± 153.88
# met_180                               1722.62 ± 85.56
# failing_top_tagger                    1662.92 ± 75.40
#
#                                              QCD cr_d      Ratio (X/Y)  \
# Cut
# sumw                                                   0.0000 ± 0.0000
# goodvertex                  -3435777617.42 ± 20656.99  1.0000 ± 0.0000
# lumi                        -3453768537.42 ± 20216.83  1.0000 ± 0.0000
# Stitching                   -3324291700.87 ± 51606.52  1.0000 ± 0.0000
# trigger_tau                   211960935.99 ± 15651.98  1.0000 ± 0.0001
# metfilters                    207328104.62 ± 15501.42  1.0000 ± 0.0001
# electron_veto                 207561766.18 ± 15386.54  1.0000 ± 0.0001
# muon_veto                     208244177.14 ± 15018.03  1.0000 ± 0.0001
# one_tau                            318500.83 ± 735.61  1.0000 ± 0.0033
# one_bjet                            10492.75 ± 177.52  1.0000 ± 0.0239
# delta_phi_jet_met_0.7_True            3025.02 ± 86.71  2.4694 ± 0.0872
# met_180                                635.23 ± 45.55  2.7118 ± 0.2365
# failing_top_tagger                     482.31 ± 35.36  3.4478 ± 0.2972
#
#                                         QCD Estimated
# Cut
# sumw                                      0.00 ± 0.00
# goodvertex                  -3435777534.80 ± 35778.96
# lumi                        -3453768454.80 ± 35016.58
# Stitching                   -3324582099.36 ± 89445.43
# trigger_tau                   211947490.60 ± 27112.00
# metfilters                    207314684.02 ± 26851.24
# electron_veto                 207553659.43 ± 26652.45
# muon_veto                     208255421.42 ± 26014.47
# one_tau                             98897.14 ± 899.33
# one_bjet                            -1967.56 ± 218.11
# delta_phi_jet_met_0.7_True            467.31 ± 235.64
# met_180                              1426.65 ± 204.24
# failing_top_tagger                   1111.44 ± 180.27

# %% [markdown]
# # Table report

# %%
table_report, SF = plotter.get_table_report()
table_report
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#                       Events ± stat  Syst up  Syst down  Contribution (%)
# tt                  5099.16 ± 19.85   761.80     792.44             58.47
# W+jets              1261.15 ± 29.22   249.05     259.66             14.46
# QCD (Data-driven)  1111.44 ± 180.27   659.94     673.32             12.74
# SingleTop           1102.75 ± 19.41   354.04     355.31             12.65
# DrellYan+jets        110.28 ± 30.37    16.13      17.48              1.26
# VV                     30.77 ± 2.82     3.08       3.21              0.35
# Higgs                   5.19 ± 3.53     2.13       2.23              0.06
# SignalTau_1000GeV   2928.39 ± 54.48      NaN        NaN               NaN
# SignalTau_1500GeV   3081.58 ± 55.71      NaN        NaN               NaN
# SignalTau_2000GeV   2801.11 ± 53.33      NaN        NaN               NaN
# SignalTau_3000GeV   2137.31 ± 47.16      NaN        NaN               NaN
# SignalTau_300GeV     363.58 ± 20.59      NaN        NaN               NaN
# SignalTau_400GeV     773.13 ± 29.64      NaN        NaN               NaN
# SignalTau_600GeV    1829.67 ± 44.05      NaN        NaN               NaN
# SignalTau_750GeV    2308.59 ± 48.98      NaN        NaN               NaN
# Total bgr          8720.74 ± 187.26  7817.42    7832.35               NaN
# QCD Ratio (X/Y)       3.448 ± 0.297      NaN        NaN               NaN
# Data/Total bgr                  nan      NaN        NaN               NaN
# Rtt (tt)                  nan ± nan      NaN        NaN               NaN

# %% [markdown]
# # Plot

# %%
variable = "lepton_met_mass" 
binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 5000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [4.02513553 4.12108837 3.97452484 3.84029071 2.5658966  3.79612993
#  4.02612598 2.40355519 2.96463809]
#  Error: [1.267734   1.29252193 1.40217051 1.67571339 1.25841477 1.17069098
#  1.12126692 0.6019983  0.53523232]
#  ===================================
# Plot saved to plots/signal/2017/lepton_met_mass_2017.pdf
#                                           $t\bar{t}$  \
# 0-20_     1246.61 ± 35.31 (Up: 184.07, Down: 190.26)
# 20-40_    1171.96 ± 34.23 (Up: 174.10, Down: 179.82)
# 40-60_     912.93 ± 30.21 (Up: 139.49, Down: 144.38)
# 60-80_       561.84 ± 23.70 (Up: 80.44, Down: 84.95)
# 80-100_      283.88 ± 16.85 (Up: 39.59, Down: 42.88)
# 100-120_     153.85 ± 12.40 (Up: 25.37, Down: 26.86)
# 120-150_     195.96 ± 14.00 (Up: 31.51, Down: 34.20)
# 150-200_     234.18 ± 15.30 (Up: 35.33, Down: 36.59)
# 200-300_     337.96 ± 18.38 (Up: 42.15, Down: 44.48)
# Total     5099.17 ± 71.41 (Up: 310.41, Down: 321.94)
#
#                                           Single Top  \
# 0-20_        303.56 ± 17.42 (Up: 68.56, Down: 69.36)
# 20-40_       277.47 ± 16.66 (Up: 73.37, Down: 73.93)
# 40-60_       221.65 ± 14.89 (Up: 63.67, Down: 63.97)
# 60-80_       124.18 ± 11.14 (Up: 35.83, Down: 35.97)
# 80-100_        53.90 ± 7.34 (Up: 13.49, Down: 13.95)
# 100-120_         25.06 ± 5.01 (Up: 6.65, Down: 6.54)
# 120-150_         28.49 ± 5.34 (Up: 5.33, Down: 5.28)
# 150-200_         24.69 ± 4.97 (Up: 3.67, Down: 4.03)
# 200-300_         43.76 ± 6.61 (Up: 8.04, Down: 8.26)
# Total     1102.75 ± 33.21 (Up: 125.51, Down: 126.54)
#
#                                            WJetToLNu  \
# 0-20_        423.39 ± 20.58 (Up: 84.69, Down: 89.53)
# 20-40_       352.55 ± 18.78 (Up: 66.77, Down: 68.53)
# 40-60_       237.32 ± 15.41 (Up: 43.03, Down: 46.10)
# 60-80_       125.49 ± 11.20 (Up: 22.99, Down: 24.34)
# 80-100_          43.67 ± 6.61 (Up: 8.33, Down: 8.77)
# 100-120_         20.91 ± 4.57 (Up: 5.15, Down: 5.07)
# 120-150_         17.82 ± 4.22 (Up: 3.18, Down: 3.05)
# 150-200_         11.69 ± 3.42 (Up: 2.28, Down: 2.43)
# 200-300_         28.32 ± 5.32 (Up: 6.00, Down: 5.68)
# Total     1261.15 ± 35.51 (Up: 118.99, Down: 124.82)
#
#                                       Diboson  \
# 0-20_      9.33 ± 3.06 (Up: 0.79, Down: 1.17)
# 20-40_     6.81 ± 2.61 (Up: 1.28, Down: 1.33)
# 40-60_     6.44 ± 2.54 (Up: 0.74, Down: 0.76)
# 60-80_     2.87 ± 1.70 (Up: 0.62, Down: 0.52)
# 80-100_    1.32 ± 1.15 (Up: 0.39, Down: 0.45)
# 100-120_   0.39 ± 0.62 (Up: 0.14, Down: 0.24)
# 120-150_   0.82 ± 0.91 (Up: 0.11, Down: 0.08)
# 150-200_   1.15 ± 1.07 (Up: 0.30, Down: 0.34)
# 200-300_   1.63 ± 1.28 (Up: 0.31, Down: 0.57)
# Total     30.77 ± 5.55 (Up: 1.90, Down: 2.17)
#
#                                       DYJetsToLNu  \
# 0-20_        59.49 ± 7.71 (Up: 9.61, Down: 12.28)
# 20-40_      36.25 ± 6.02 (Up: 12.92, Down: 11.98)
# 40-60_         8.91 ± 2.99 (Up: 2.65, Down: 4.96)
# 60-80_         7.27 ± 2.70 (Up: 2.91, Down: 2.00)
# 80-100_        2.27 ± 1.51 (Up: 1.97, Down: 3.32)
# 100-120_       1.67 ± 1.29 (Up: 2.69, Down: 1.22)
# 120-150_       1.72 ± 1.31 (Up: 0.42, Down: 0.76)
# 150-200_      -4.04 ± 2.01 (Up: 4.77, Down: 1.73)
# 200-300_      -3.26 ± 1.81 (Up: 2.31, Down: 2.71)
# Total     110.28 ± 11.18 (Up: 17.72, Down: 18.61)
#
#                                        Higgs SignalTau_1000GeV  \
# 0-20_     0.37 ± 0.61 (Up: 0.26, Down: 0.26)      16.62 ± 0.00
# 20-40_    0.53 ± 0.72 (Up: 0.23, Down: 0.23)      13.53 ± 0.00
# 40-60_    0.33 ± 0.58 (Up: 0.27, Down: 0.27)      13.65 ± 0.00
# 60-80_    3.83 ± 1.96 (Up: 1.30, Down: 1.42)      17.73 ± 0.00
# 80-100_   0.08 ± 0.28 (Up: 0.05, Down: 0.06)      12.23 ± 0.00
# 100-120_  0.02 ± 0.13 (Up: 0.02, Down: 0.03)      18.86 ± 0.00
# 120-150_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      35.81 ± 0.00
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      67.34 ± 0.00
# 200-300_  0.03 ± 0.19 (Up: 0.03, Down: 0.03)    2732.61 ± 0.00
# Total     5.19 ± 2.28 (Up: 1.37, Down: 1.49)    2928.39 ± 0.00
#
#          SignalTau_1500GeV SignalTau_2000GeV SignalTau_3000GeV  \
# 0-20_          9.86 ± 0.00       6.98 ± 0.00      10.55 ± 0.00
# 20-40_        11.82 ± 0.00       8.07 ± 0.00       7.28 ± 0.00
# 40-60_        11.48 ± 0.00      10.37 ± 0.00       8.27 ± 0.00
# 60-80_         7.27 ± 0.00       5.47 ± 0.00       7.12 ± 0.00
# 80-100_       20.16 ± 0.00       9.97 ± 0.00      10.41 ± 0.00
# 100-120_      15.13 ± 0.00      10.44 ± 0.00      12.97 ± 0.00
# 120-150_      22.23 ± 0.00      27.23 ± 0.00      20.73 ± 0.00
# 150-200_      53.03 ± 0.00      41.32 ± 0.00      43.02 ± 0.00
# 200-300_    2930.59 ± 0.00    2681.24 ± 0.00    2016.97 ± 0.00
# Total       3081.58 ± 0.00    2801.11 ± 0.00    2137.31 ± 0.00
#
#          SignalTau_300GeV SignalTau_400GeV SignalTau_600GeV SignalTau_750GeV  \
# 0-20_        11.19 ± 0.00     12.48 ± 0.00      6.79 ± 0.00     15.57 ± 0.00
# 20-40_        6.73 ± 0.00     12.03 ± 0.00      7.37 ± 0.00      9.24 ± 0.00
# 40-60_        2.32 ± 0.00      5.30 ± 0.00      9.83 ± 0.00     14.61 ± 0.00
# 60-80_        8.95 ± 0.00     11.45 ± 0.00     13.53 ± 0.00     12.53 ± 0.00
# 80-100_      13.60 ± 0.00      8.97 ± 0.00     21.72 ± 0.00     13.78 ± 0.00
# 100-120_     20.94 ± 0.00     22.34 ± 0.00     12.82 ± 0.00     20.50 ± 0.00
# 120-150_     34.09 ± 0.00     36.89 ± 0.00     30.77 ± 0.00     27.53 ± 0.00
# 150-200_     78.07 ± 0.00     92.34 ± 0.00     93.61 ± 0.00     89.57 ± 0.00
# 200-300_    187.68 ± 0.00    571.33 ± 0.00   1633.23 ± 0.00   2105.25 ± 0.00
# Total       363.58 ± 0.00    773.13 ± 0.00   1829.67 ± 0.00   2308.58 ± 0.00
#
#                                                   QCD  \
# 0-20_        58.91 ± 95.00 (Up: 127.92, Down: 167.26)
# 20-40_     150.72 ± 103.90 (Up: 125.28, Down: 169.76)
# 40-60_      189.81 ± 106.30 (Up: 92.77, Down: 136.48)
# 60-80_        171.90 ± 98.53 (Up: 57.18, Down: 88.21)
# 80-100_        68.73 ± 46.08 (Up: 17.40, Down: 27.88)
# 100-120_       77.36 ± 45.18 (Up: 17.25, Down: 25.81)
# 120-150_       87.49 ± 49.48 (Up: 18.74, Down: 34.95)
# 150-200_       79.31 ± 35.05 (Up: 12.42, Down: 16.65)
# 200-300_      227.51 ± 63.64 (Up: 28.41, Down: 35.63)
# Total     1111.75 ± 229.61 (Up: 214.12, Down: 295.66)
#
#                                              Total MC  Data / Total MC
# 0-20_     2101.66 ± 105.20 (Up: 249.43, Down: 277.77)              NaN
# 20-40_    1996.28 ± 112.43 (Up: 236.68, Down: 267.32)              NaN
# 40-60_    1577.40 ± 112.64 (Up: 184.33, Down: 213.81)              NaN
# 60-80_     997.38 ± 102.64 (Up: 107.53, Down: 129.96)              NaN
# 80-100_       453.84 ± 50.08 (Up: 46.11, Down: 53.84)              NaN
# 100-120_      279.25 ± 47.37 (Up: 31.92, Down: 38.18)              NaN
# 120-150_      332.31 ± 51.89 (Up: 37.19, Down: 49.28)              NaN
# 150-200_      346.99 ± 38.78 (Up: 38.00, Down: 40.51)              NaN
# 200-300_      635.95 ± 66.82 (Up: 51.87, Down: 57.93)              NaN
# Total     8721.05 ± 245.65 (Up: 415.25, Down: 472.23)              NaN

# %%
variable = "lepton_pt" 
binning = [0, 50, 100, 150, 200, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "met" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "lepton_met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 20000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "recoil_pt" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "ST_met" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "ST" 
binning =[100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "ST_full" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "jet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400, 500, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "bjet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "lepton_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "bjet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "jet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "recoil_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "lepton_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "bjet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "jet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "njets_full"
binning = [2, 3, 4, 5, 6, 7, 8, 9, 10]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "nmuons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "nelectrons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "ntaus"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0


y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "nbjets"
binning = [0, 1, 2, 3, 4]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "njets"
binning = [0, 1, 2, 3, 4, 5, 6, 7, 8]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 300000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %%
variable = "npvs"
binning = np.arange(6, 52 + 2, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

# %% [markdown]
# # QCD shape

# %%
qcd_table = plotter.qcd_comparison(distribution = "lepton_met_mass", 
                                   binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300], 
                                   overflow = True, 
                                   underflow = True, 
                                   normalize= True,
                                   log_scale = True,
                                   y_range = (0.01, 1))
qcd_table

# %% [markdown]
# # Root

# %%
include_plots = False # Variable que nos permite ver los gráficos, si está en false generará unicamente el archivo root y no veremos nada

events, percentages = plotter.get_root_files(CR_name = "signal", with_plots = include_plots, distribution = "lepton_met_mass", binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300])
events

# %%
percentages

# %%
sorted_df = percentages["Total MC"].sort_values(by="Up (%)", ascending=False)
sorted_df

# %% [markdown]
# # Backup

# %%
pkls, jsons, norms, sumw = plotter.get_maps()

# %%
import numpy as np
from src.Plotter import Plotter
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# --------------------
# General configs
# --------------------
year = "2017"
case = "trigger_weights"   # no_weights  trigger_weights;  weighted_ISR
samples_folder = f"/eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/signal/{case}/{year}" 
output_folder = f"plots/signal/{year}"
lepton_flavor = "tau"
control_region = "signal"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False


# ---------------------
# Include signal samples
# --------------------
include_signal_samples = True


# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True

stadistical_error_using = "cutflow_raw" #  Cutflow_raw: Eventos sin pesar.
normalized_to = "sumw_case_3"                  # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw; sumw_case_1; sumw_case_1; sumw_case_3


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# -------------------------
#    QCD estimation
# -------------------------
activate_qcd_data_driven = True
cr_B_folder = f"/eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_{case}/cr_b/{year}"
cr_C_folder = f"/eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_{case}/cr_c/{year}"
cr_D_folder = f"/eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_{case}/cr_d/{year}"

qcd_ratio_integrated = False # True si se quiere calcular el transfer factor con los valores integrados
qcd_shape = "cr_b"
qcd_ratio = ["cr_c", "cr_d"] # [Num, Den]

# -------------------------
#    Signal region
# -------------------------
is_signal = True
signal_superposition = True

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  control_region = control_region,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  include_signal_samples = include_signal_samples,                  

                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                  applied_data_driven = activate_qcd_data_driven,
                  cr_B_folder = cr_B_folder,
                  cr_C_folder = cr_C_folder,
                  cr_D_folder = cr_D_folder,

                  is_SR = is_signal,
                  signal_superposition = signal_superposition,

                  qcd_shape = qcd_shape,
                  qcd_ratio = qcd_ratio,   # cr_c/cr_d
                  qcd_ratio_integrated = qcd_ratio_integrated                  
                 )
# Out:
# Samples directory set to: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/signal/trigger_weights/2017
# Output directory set to: plots/signal/2017
# ROOT files directory set to: plots/signal/2017/root
#  Reading pkl files from: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/signal/trigger_weights/2017/summary/pkl
#  Reading json files from: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/signal/trigger_weights/2017/summary/metadata
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3

# %% [markdown]
# # Cutflow

# %%
cutflow_table, error, qcd = plotter.get_table_cutflow(variation = "cutflow", combined_samples = True)
cutflow_table
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#                                               tt           SingleTop  \
# sumw                                 34427414.76         12460301.64
# goodvertex                    34427414.75 ± 0.12  12460301.42 ± 0.59
# lumi                          34427414.75 ± 0.12  12460301.42 ± 0.59
# Stitching                     34427414.75 ± 0.12  12460301.42 ± 0.59
# trigger_tau                  2063490.18 ± 346.96  316076.96 ± 281.47
# metfilters                   2060225.91 ± 346.65  315430.17 ± 281.16
# electron_veto                1716141.94 ± 320.99  268785.89 ± 257.96
# muon_veto                     921454.32 ± 242.74  143808.54 ± 183.23
# one_tau                         55363.92 ± 62.96     8499.71 ± 53.64
# one_bjet                        27460.38 ± 44.41     4103.16 ± 37.81
# delta_phi_jet_met_0.7_False     22078.04 ± 39.80     3527.16 ± 34.89
# met_180                          8119.16 ± 25.10     1491.85 ± 23.34
# failing_top_tagger               5098.40 ± 19.85     1101.98 ± 19.40
#
#                                                W+jets                  VV  \
# sumw                                    2692805901.65          4799650.80
# goodvertex                     2692804267.03 ± 207.32   4799650.65 ± 0.45
# lumi                           2692804267.03 ± 207.32   4799650.65 ± 0.45
# Stitching                    2563617959.14 ± 47585.83   4799650.65 ± 0.45
# trigger_tau                      7925651.61 ± 3888.77  100300.29 ± 148.80
# metfilters                       7915423.05 ± 3886.01  100122.22 ± 148.65
# electron_veto                    7101916.56 ± 3578.26   87017.09 ± 138.19
# muon_veto                        4211013.43 ± 3128.38   55596.18 ± 110.03
# one_tau                            168708.13 ± 497.54     2337.06 ± 24.43
# one_bjet                              3687.48 ± 52.83        78.67 ± 4.44
# delta_phi_jet_met_0.7_False           3160.46 ± 50.00        68.04 ± 4.14
# met_180                               1450.73 ± 31.44        34.66 ± 3.01
# failing_top_tagger                    1260.91 ± 29.22        30.77 ± 2.82
#
#                                       DrellYan+jets              Higgs  \
# sumw                                  1116392720.00         1520283.48
# goodvertex                   1116390646.41 ± 208.11  1520283.44 ± 5.58
# lumi                         1116390646.41 ± 208.11  1520283.44 ± 5.58
# Stitching                    1116390646.41 ± 208.11  1520283.44 ± 5.58
# trigger_tau                     723793.99 ± 2582.44  25901.21 ± 194.68
# metfilters                      721811.49 ± 2578.61  25860.00 ± 194.42
# electron_veto                   697967.90 ± 2534.62  21483.64 ± 187.14
# muon_veto                       172222.54 ± 1391.01  11768.17 ± 153.90
# one_tau                           11683.81 ± 320.76     466.80 ± 25.16
# one_bjet                             506.72 ± 71.62      25.45 ± 10.86
# delta_phi_jet_met_0.7_False          384.38 ± 63.22       20.21 ± 9.72
# met_180                              136.06 ± 32.49        5.32 ± 3.54
# failing_top_tagger                   110.28 ± 30.37        5.19 ± 3.53
#
#                              SignalTau_1000GeV  SignalTau_1500GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.07    41480.00 ± 1.07
# lumi                           41480.00 ± 1.07    41480.00 ± 1.07
# Stitching                      41480.00 ± 1.07    41480.00 ± 1.07
# trigger_tau                   26977.28 ± 99.66   28382.45 ± 97.13
# metfilters                    26903.74 ± 99.77   28256.57 ± 97.38
# electron_veto                23551.63 ± 103.58  24745.66 ± 102.59
# muon_veto                    21234.37 ± 104.51  22071.40 ± 104.34
# one_tau                        9377.09 ± 88.11    9764.71 ± 89.28
# one_bjet                       4219.45 ± 64.50    4311.19 ± 65.04
# delta_phi_jet_met_0.7_False    3634.22 ± 60.26    3637.87 ± 60.22
# met_180                        3087.61 ± 55.89    3274.50 ± 57.36
# failing_top_tagger             2928.12 ± 54.48    3083.16 ± 55.73
#
#                              SignalTau_2000GeV  SignalTau_3000GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.07    41480.00 ± 1.08
# lumi                           41480.00 ± 1.07    41480.00 ± 1.08
# Stitching                      41480.00 ± 1.07    41480.00 ± 1.08
# trigger_tau                   27557.97 ± 98.65  22427.57 ± 104.35
# metfilters                    27406.94 ± 98.91  22307.51 ± 104.41
# electron_veto                23849.47 ± 103.36  19577.98 ± 104.65
# muon_veto                    21030.35 ± 104.56  17280.05 ± 103.43
# one_tau                        8947.74 ± 86.67    7142.75 ± 79.99
# one_bjet                       3951.69 ± 62.56    3125.90 ± 56.60
# delta_phi_jet_met_0.7_False    3318.40 ± 57.81    2595.61 ± 51.92
# met_180                        2989.57 ± 55.04    2265.05 ± 48.57
# failing_top_tagger             2802.09 ± 53.34    2136.68 ± 47.15
#
#                             SignalTau_300GeV  SignalTau_400GeV  \
# sumw                                     NaN               NaN
# goodvertex                   41480.00 ± 1.08   41480.00 ± 1.08
# lumi                         41480.00 ± 1.08   41480.00 ± 1.08
# Stitching                    41480.00 ± 1.08   41480.00 ± 1.08
# trigger_tau                  8417.10 ± 84.69  13763.57 ± 99.10
# metfilters                   8410.22 ± 84.66  13752.15 ± 99.08
# electron_veto                7556.99 ± 81.24  12238.56 ± 95.99
# muon_veto                    6777.56 ± 77.87  11099.03 ± 93.24
# one_tau                      2144.31 ± 48.33   4042.01 ± 64.04
# one_bjet                     1015.43 ± 34.21   1789.75 ± 44.61
# delta_phi_jet_met_0.7_False   935.29 ± 32.85   1620.48 ± 42.51
# met_180                       391.70 ± 21.39    830.09 ± 30.76
# failing_top_tagger            362.67 ± 20.57    772.59 ± 29.63
#
#                               SignalTau_600GeV   SignalTau_750GeV  \
# sumw                                       NaN                NaN
# goodvertex                     41480.00 ± 1.08    41480.00 ± 1.08
# lumi                           41480.00 ± 1.08    41480.00 ± 1.08
# Stitching                      41480.00 ± 1.08    41480.00 ± 1.08
# trigger_tau                  21078.64 ± 104.76  23957.97 ± 103.32
# metfilters                   21038.45 ± 104.76  23909.60 ± 103.36
# electron_veto                18592.26 ± 104.21  21091.24 ± 104.61
# muon_veto                    16924.81 ± 102.99  19133.14 ± 104.32
# one_tau                        6884.84 ± 78.99    8150.25 ± 83.92
# one_bjet                       3100.38 ± 56.71    3602.86 ± 60.38
# delta_phi_jet_met_0.7_False    2755.99 ± 53.68    3155.18 ± 56.83
# met_180                        1942.44 ± 45.42    2457.60 ± 50.53
# failing_top_tagger             1830.53 ± 44.06    2307.68 ± 48.97
#
#                                                 Total
# sumw                                    3862406272.34
# goodvertex                     3862734403.70 ± 293.82
# lumi                           3862734403.70 ± 293.82
# Stitching                    3733548095.80 ± 47586.28
# trigger_tau                     11327776.78 ± 4704.23
# metfilters                      11310858.04 ± 4699.81
# electron_veto                   10044516.81 ± 4419.56
# muon_veto                        5651413.88 ± 3453.94
# one_tau                            303513.12 ± 638.64
# one_bjet                            60978.49 ± 192.33
# delta_phi_jet_met_0.7_False         50891.35 ± 178.05
# met_180                             28476.34 ± 145.13
# failing_top_tagger                  23831.06 ± 139.10

# %%
qcd
# Out:
#                                              QCD cr_b  \
# Cut
# sumw
# goodvertex                  -3435777465.91 ± 20656.99
# lumi                        -3453768385.91 ± 20216.84
# Stitching                   -3324582098.11 ± 51701.92
# trigger_tau                   211947491.35 ± 15657.39
# metfilters                    207314686.18 ± 15506.87
# electron_veto                 207553653.05 ± 15391.52
# muon_veto                     208255420.38 ± 15020.69
# one_tau                             98897.75 ± 839.32
# one_bjet                            -1967.75 ± 212.97
# delta_phi_jet_met_0.7_True             189.43 ± 95.19
# met_180                                526.43 ± 59.72
# failing_top_tagger                     322.17 ± 44.29
#
#                                              QCD cr_c  \
# Cut
# sumw
# goodvertex                  -3435777641.65 ± 20656.99
# lumi                        -3453768561.65 ± 20216.83
# Stitching                   -3324291706.66 ± 51606.52
# trigger_tau                   211960930.79 ± 15651.98
# metfilters                    207328099.64 ± 15501.42
# electron_veto                 207561760.42 ± 15386.54
# muon_veto                     208244176.36 ± 15018.03
# one_tau                            318499.78 ± 735.61
# one_bjet                            10492.94 ± 177.52
# delta_phi_jet_met_0.7_True           7467.38 ± 153.91
# met_180                               1721.48 ± 85.56
# failing_top_tagger                    1662.26 ± 75.41
#
#                                              QCD cr_d      Ratio (X/Y)  \
# Cut
# sumw                                                   0.0000 ± 0.0000
# goodvertex                  -3435777654.91 ± 20656.99  1.0000 ± 0.0000
# lumi                        -3453768574.91 ± 20216.83  1.0000 ± 0.0000
# Stitching                   -3324291705.99 ± 51606.52  1.0000 ± 0.0000
# trigger_tau                   211960931.08 ± 15651.98  1.0000 ± 0.0001
# metfilters                    207328100.18 ± 15501.42  1.0000 ± 0.0001
# electron_veto                 207561761.51 ± 15386.54  1.0000 ± 0.0001
# muon_veto                     208244172.03 ± 15018.03  1.0000 ± 0.0001
# one_tau                            318500.55 ± 735.61  1.0000 ± 0.0033
# one_bjet                            10492.71 ± 177.52  1.0000 ± 0.0239
# delta_phi_jet_met_0.7_True            3025.98 ± 86.71  2.4678 ± 0.0871
# met_180                                634.17 ± 45.55  2.7145 ± 0.2371
# failing_top_tagger                     481.92 ± 35.36  3.4492 ± 0.2975
#
#                                         QCD Estimated
# Cut
# sumw                                      0.00 ± 0.00
# goodvertex                  -3435777452.65 ± 35778.95
# lumi                        -3453768372.65 ± 35016.58
# Stitching                   -3324582098.78 ± 89445.43
# trigger_tau                   211947491.06 ± 27112.00
# metfilters                    207314685.64 ± 26851.24
# electron_veto                 207553651.96 ± 26652.45
# muon_veto                     208255424.71 ± 26014.46
# one_tau                             98897.51 ± 899.33
# one_bjet                            -1967.79 ± 218.12
# delta_phi_jet_met_0.7_True            467.47 ± 235.48
# met_180                              1429.02 ± 204.60
# failing_top_tagger                   1111.24 ± 180.35

# %% [markdown]
# # Table report

# %%
table_report, SF = plotter.get_table_report()
table_report
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#                       Events ± stat  Syst up  Syst down  Contribution (%)
# tt                  5098.40 ± 19.85   689.93     712.93             58.48
# W+jets              1260.91 ± 29.22   170.47     173.41             14.46
# QCD (Data-driven)  1111.24 ± 180.35   509.17     517.75             12.75
# SingleTop           1101.98 ± 19.40   129.57     132.78             12.64
# DrellYan+jets        110.28 ± 30.37    12.42      13.20              1.26
# VV                     30.77 ± 2.82     3.01       3.14              0.35
# Higgs                   5.19 ± 3.53     1.06       1.09              0.06
# SignalTau_1000GeV   2928.12 ± 54.48      NaN        NaN               NaN
# SignalTau_1500GeV   3083.16 ± 55.73      NaN        NaN               NaN
# SignalTau_2000GeV   2802.09 ± 53.34      NaN        NaN               NaN
# SignalTau_3000GeV   2136.68 ± 47.15      NaN        NaN               NaN
# SignalTau_300GeV     362.67 ± 20.57      NaN        NaN               NaN
# SignalTau_400GeV     772.59 ± 29.63      NaN        NaN               NaN
# SignalTau_600GeV    1830.53 ± 44.06      NaN        NaN               NaN
# SignalTau_750GeV    2307.68 ± 48.97      NaN        NaN               NaN
# Total bgr          8718.77 ± 187.33 29413.93   29446.87               NaN
# QCD Ratio (X/Y)       3.449 ± 0.297      NaN        NaN               NaN
# Data/Total bgr                  nan      NaN        NaN               NaN
# Rtt (tt)                  nan ± nan      NaN        NaN               NaN

# %% [markdown]
# # Plot

# %%
variable = "lepton_met_mass" 
binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 5000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [4.05176945 4.09352728 4.0096894  3.83035456 2.56426182 3.7967153
#  4.01545897 2.40219158 2.96482604]
#  Error: [1.2846405  1.27620806 1.41544852 1.67298837 1.26276977 1.1718975
#  1.11944672 0.60119664 0.53605446]
#  ===================================
# Plot saved to plots/signal/2017/lepton_met_mass_2017.pdf
#                                           $t\bar{t}$  \
# 0-20_     1245.99 ± 35.30 (Up: 171.67, Down: 176.83)
# 20-40_    1172.71 ± 34.24 (Up: 160.53, Down: 165.19)
# 40-60_     912.64 ± 30.21 (Up: 130.16, Down: 133.73)
# 60-80_       561.27 ± 23.69 (Up: 74.31, Down: 77.81)
# 80-100_      283.67 ± 16.84 (Up: 35.85, Down: 37.50)
# 100-120_     154.11 ± 12.41 (Up: 23.47, Down: 24.99)
# 120-150_     195.92 ± 14.00 (Up: 28.98, Down: 30.80)
# 150-200_     234.08 ± 15.30 (Up: 32.69, Down: 33.17)
# 200-300_     338.02 ± 18.39 (Up: 36.38, Down: 37.23)
# Total     5098.41 ± 71.40 (Up: 287.70, Down: 296.58)
#
#                                         Single Top  \
# 0-20_      303.12 ± 17.41 (Up: 33.24, Down: 34.54)
# 20-40_     277.66 ± 16.66 (Up: 32.35, Down: 33.16)
# 40-60_     221.63 ± 14.89 (Up: 27.58, Down: 28.27)
# 60-80_     124.39 ± 11.15 (Up: 15.80, Down: 15.91)
# 80-100_        53.64 ± 7.32 (Up: 6.31, Down: 6.67)
# 100-120_       24.98 ± 5.00 (Up: 4.00, Down: 3.95)
# 120-150_       28.53 ± 5.34 (Up: 2.54, Down: 2.30)
# 150-200_       24.63 ± 4.96 (Up: 3.00, Down: 3.38)
# 200-300_       43.40 ± 6.59 (Up: 6.59, Down: 5.94)
# Total     1101.98 ± 33.20 (Up: 57.24, Down: 58.80)
#
#                                          WJetToLNu  \
# 0-20_      421.93 ± 20.54 (Up: 63.58, Down: 64.67)
# 20-40_     353.50 ± 18.80 (Up: 47.89, Down: 47.91)
# 40-60_     237.63 ± 15.42 (Up: 28.64, Down: 29.52)
# 60-80_     125.40 ± 11.20 (Up: 17.47, Down: 17.88)
# 80-100_        43.68 ± 6.61 (Up: 6.40, Down: 6.50)
# 100-120_       20.91 ± 4.57 (Up: 4.26, Down: 3.68)
# 120-150_       17.83 ± 4.22 (Up: 1.99, Down: 1.85)
# 150-200_       11.68 ± 3.42 (Up: 0.88, Down: 1.11)
# 200-300_       28.34 ± 5.32 (Up: 4.70, Down: 3.61)
# Total     1260.91 ± 35.51 (Up: 86.88, Down: 87.99)
#
#                                       Diboson  \
# 0-20_      9.33 ± 3.06 (Up: 0.77, Down: 0.87)
# 20-40_     6.81 ± 2.61 (Up: 1.14, Down: 1.24)
# 40-60_     6.44 ± 2.54 (Up: 0.74, Down: 0.75)
# 60-80_     2.87 ± 1.70 (Up: 0.49, Down: 0.39)
# 80-100_    1.32 ± 1.15 (Up: 0.31, Down: 0.18)
# 100-120_   0.39 ± 0.62 (Up: 0.14, Down: 0.21)
# 120-150_   0.82 ± 0.91 (Up: 0.06, Down: 0.06)
# 150-200_   1.15 ± 1.07 (Up: 0.26, Down: 0.15)
# 200-300_   1.63 ± 1.28 (Up: 0.24, Down: 0.24)
# Total     30.77 ± 5.55 (Up: 1.71, Down: 1.78)
#
#                                       DYJetsToLNu  \
# 0-20_         57.65 ± 7.59 (Up: 7.57, Down: 7.69)
# 20-40_      36.25 ± 6.02 (Up: 12.30, Down: 11.43)
# 40-60_        10.75 ± 3.28 (Up: 2.54, Down: 2.55)
# 60-80_         7.27 ± 2.70 (Up: 2.70, Down: 1.87)
# 80-100_        2.27 ± 1.51 (Up: 1.51, Down: 1.51)
# 100-120_       1.67 ± 1.29 (Up: 2.68, Down: 1.18)
# 120-150_       1.72 ± 1.31 (Up: 0.07, Down: 0.40)
# 150-200_      -4.04 ± 2.01 (Up: 4.71, Down: 1.63)
# 200-300_      -3.26 ± 1.81 (Up: 1.91, Down: 1.92)
# Total     110.28 ± 11.18 (Up: 16.05, Down: 14.49)
#
#                                        Higgs SignalTau_1000GeV  \
# 0-20_     0.37 ± 0.61 (Up: 0.08, Down: 0.07)      16.62 ± 0.00
# 20-40_    0.53 ± 0.72 (Up: 0.11, Down: 0.10)      13.53 ± 0.00
# 40-60_    0.33 ± 0.58 (Up: 0.09, Down: 0.09)      13.65 ± 0.00
# 60-80_    3.83 ± 1.96 (Up: 0.95, Down: 0.98)      17.73 ± 0.00
# 80-100_   0.08 ± 0.28 (Up: 0.05, Down: 0.05)      12.23 ± 0.00
# 100-120_  0.02 ± 0.13 (Up: 0.02, Down: 0.03)      18.86 ± 0.00
# 120-150_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      35.81 ± 0.00
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      67.34 ± 0.00
# 200-300_  0.03 ± 0.19 (Up: 0.01, Down: 0.01)    2732.35 ± 0.00
# Total     5.19 ± 2.28 (Up: 0.97, Down: 0.99)    2928.12 ± 0.00
#
#          SignalTau_1500GeV SignalTau_2000GeV SignalTau_3000GeV  \
# 0-20_          9.86 ± 0.00       6.98 ± 0.00      10.55 ± 0.00
# 20-40_        11.82 ± 0.00       8.07 ± 0.00       7.28 ± 0.00
# 40-60_        11.48 ± 0.00      10.37 ± 0.00       9.32 ± 0.00
# 60-80_         7.27 ± 0.00       5.47 ± 0.00       7.12 ± 0.00
# 80-100_       20.16 ± 0.00       9.97 ± 0.00      10.41 ± 0.00
# 100-120_      15.13 ± 0.00      10.44 ± 0.00      12.97 ± 0.00
# 120-150_      22.23 ± 0.00      27.23 ± 0.00      20.73 ± 0.00
# 150-200_      53.03 ± 0.00      41.32 ± 0.00      43.02 ± 0.00
# 200-300_    2932.17 ± 0.00    2682.23 ± 0.00    2015.28 ± 0.00
# Total       3083.16 ± 0.00    2802.09 ± 0.00    2136.68 ± 0.00
#
#          SignalTau_300GeV SignalTau_400GeV SignalTau_600GeV SignalTau_750GeV  \
# 0-20_        11.19 ± 0.00     12.48 ± 0.00      6.79 ± 0.00     16.32 ± 0.00
# 20-40_        6.73 ± 0.00     12.03 ± 0.00      7.37 ± 0.00      8.50 ± 0.00
# 40-60_        2.32 ± 0.00      5.30 ± 0.00      9.83 ± 0.00     14.61 ± 0.00
# 60-80_        8.95 ± 0.00     11.45 ± 0.00     13.53 ± 0.00     12.53 ± 0.00
# 80-100_      13.60 ± 0.00      9.80 ± 0.00     21.72 ± 0.00     13.78 ± 0.00
# 100-120_     20.94 ± 0.00     21.50 ± 0.00     12.82 ± 0.00     19.62 ± 0.00
# 120-150_     34.94 ± 0.00     36.07 ± 0.00     30.77 ± 0.00     28.40 ± 0.00
# 150-200_     76.31 ± 0.00     92.34 ± 0.00     93.61 ± 0.00     89.57 ± 0.00
# 200-300_    187.68 ± 0.00    571.60 ± 0.00   1634.08 ± 0.00   2104.35 ± 0.00
# Total       362.67 ± 0.00    772.59 ± 0.00   1830.53 ± 0.00   2307.68 ± 0.00
#
#                                                   QCD  \
# 0-20_         58.48 ± 95.61 (Up: 85.65, Down: 134.06)
# 20-40_      151.71 ± 103.34 (Up: 71.22, Down: 131.11)
# 40-60_      190.50 ± 107.06 (Up: 55.19, Down: 113.03)
# 60-80_        171.08 ± 98.21 (Up: 31.24, Down: 72.33)
# 80-100_        68.69 ± 46.15 (Up: 11.53, Down: 24.96)
# 100-120_       77.43 ± 45.21 (Up: 10.61, Down: 21.02)
# 120-150_       86.60 ± 49.30 (Up: 12.12, Down: 29.52)
# 150-200_        79.17 ± 35.01 (Up: 8.58, Down: 12.92)
# 200-300_      227.71 ± 63.70 (Up: 19.84, Down: 28.06)
# Total     1111.36 ± 229.82 (Up: 131.49, Down: 236.77)
#
#                                              Total MC  Data / Total MC
# 0-20_     2096.87 ± 105.73 (Up: 204.97, Down: 233.83)              NaN
# 20-40_    1999.18 ± 111.93 (Up: 185.29, Down: 219.10)              NaN
# 40-60_    1579.92 ± 113.36 (Up: 146.88, Down: 179.82)              NaN
# 60-80_      996.11 ± 102.33 (Up: 84.04, Down: 108.92)              NaN
# 80-100_       453.33 ± 50.14 (Up: 38.74, Down: 46.02)              NaN
# 100-120_      279.51 ± 47.39 (Up: 26.55, Down: 33.12)              NaN
# 120-150_      331.42 ± 51.72 (Up: 31.57, Down: 42.76)              NaN
# 150-200_      346.68 ± 38.74 (Up: 34.27, Down: 35.81)              NaN
# 200-300_      635.88 ± 66.88 (Up: 42.27, Down: 47.17)              NaN
# Total     8718.89 ± 245.84 (Up: 333.38, Down: 394.25)              NaN

# %%
variable = "lepton_pt" 
binning = [0, 50, 100, 150, 200, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 3.16660767  8.10503037  2.95131735 35.90228943  1.8616142 ]
#  Error: [  0.30525414   4.49080954   1.81659369 157.62655767   0.381882  ]
#  ===================================
# Plot saved to plots/signal/2017/lepton_pt_2017.pdf

# %%
variable = "met" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 3.48882202  3.24737366 12.5266659   2.42921169  3.31707072  1.85001184]
#  Error: [0.6159816  0.53839056 8.27324839 0.64522041 1.63858583 0.42743671]
#  ===================================
# Plot saved to plots/signal/2017/met_2017.pdf

# %%
variable = "lepton_met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 20000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 3.15648394  5.51920059  3.02176275  4.47166543  4.17768707  1.51468476
#   2.1703986   3.0680834   3.23537558  5.22145389  1.92190738  2.19218947
#   2.93590298  2.48156835 36.47288458  4.10534114  4.16898667  3.01060535
#   5.86621714  6.00078274  2.41253151  3.95229315  2.43640465 25.45513637
#   4.15859031  4.89536543  2.56540459  2.36417636  4.06628188  2.54817259
#   2.96782787  1.59708909]
#  Error: [  1.09322641   3.33072934   1.69644481   2.30967836   3.78412364
#    0.95967725   1.33035846   1.79780534   1.87339119   4.66856595
#    1.23975617   1.31058937   1.86536796   0.97306541 130.32979292
#    1.72590735   2.23782818   1.28375153   5.83962716   4.62731328
#    1.42218658   2.76602177   1.34846252  77.30138073   3.21735273
#    3.07957236   1.15613176   1.35913357   3.25682206   1.08454229
#    1.09109723   0.56409223]
#  ===================================
# Plot saved to plots/signal/2017/lepton_met_phi_2017.pdf
#                                                                               $t\bar{t}$  \
# -3.141592653589793--2.941592653589793_            65.73 ± 8.11 (Up: 81.33, Down: 130.95)
# -2.941592653589793--2.7415926535897928_           62.15 ± 7.88 (Up: 76.91, Down: 123.90)
# -2.7415926535897928--2.5415926535897926_          55.05 ± 7.42 (Up: 68.31, Down: 110.15)
# -2.5415926535897926--2.3415926535897924_           48.94 ± 7.00 (Up: 60.50, Down: 97.79)
# -2.3415926535897924--2.1415926535897922_           37.55 ± 6.13 (Up: 46.39, Down: 75.13)
# -2.1415926535897922--1.941592653589792_            30.45 ± 5.52 (Up: 36.85, Down: 60.67)
# -1.941592653589792--1.7415926535897919_            30.51 ± 5.52 (Up: 36.50, Down: 60.92)
# -1.7415926535897919--1.5415926535897917_           29.52 ± 5.43 (Up: 35.07, Down: 58.88)
# -1.941592653589792--1.7415926535897919_                 NaN
# -1.7415926535897919--1.5415926535897917_                NaN
# -1.5415926535897917--1.3415926535897915_                NaN
# -1.3415926535897915--1.1415926535897913_                NaN
# -1.1415926535897913--0.9415926535897912_                NaN
# -0.9415926535897912--0.741592653589791_                 NaN
# -0.741592653589791--0.5415926535897908_                 NaN
# -0.5415926535897908--0.34159265358979063_               NaN
# -0.34159265358979063--0.14159265358979045_              NaN
# -0.14159265358979045-0.058407346410209726_              NaN
# 0.058407346410209726-0.2584073464102099_                NaN
# 0.2584073464102099-0.4584073464102101_                  NaN
# 0.4584073464102101-0.6584073464102103_                  NaN
# 0.6584073464102103-0.8584073464102104_                  NaN
# 0.8584073464102104-1.0584073464102106_                  NaN
# 1.0584073464102106-1.2584073464102108_                  NaN
# 1.2584073464102108-1.458407346410211_                   NaN
# 1.458407346410211-1.6584073464102111_                   NaN
# 1.6584073464102111-1.8584073464102113_                  NaN
# 1.8584073464102113-2.0584073464102115_                  NaN
# 2.0584073464102115-2.2584073464102117_                  NaN
# 2.2584073464102117-2.458407346410212_                   NaN
# 2.458407346410212-2.658407346410212_                    NaN
# 2.658407346410212-2.858407346410212_                    NaN
# 2.858407346410212-3.0584073464102124_                   NaN
# 3.0584073464102124-3.2584073464102126_                  NaN
# Total                                                   NaN

# %%
variable = "recoil_pt" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 3.48882202  3.24737366 12.5266659   2.42921169  3.31707072  1.85001184]
#  Error: [0.6159816  0.53839056 8.27324839 0.64522041 1.63858583 0.42743671]
#  ===================================
# Plot saved to plots/signal/2017/recoil_pt_2017.pdf

# %%
variable = "ST_met" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [8.56130431 6.5206742  4.49477779 3.56974381 2.73956577 1.86927882
#  1.69321356]
#  Error: [2.35544984 2.37004167 1.25342546 0.94237556 0.73292569 0.60139386
#  0.30874118]
#  ===================================
# Plot saved to plots/signal/2017/ST_met_2017.pdf

# %%
variable = "ST" 
binning =[100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 7.21016672  4.48485197 18.92972826  4.69148126  3.65214444  3.5395403
#   2.36798552  1.6838633   1.73898304  2.21335734  1.17090586]
#  Error: [ 1.94945877  1.5193188  20.87062416  1.62350243  0.93043464  0.97741264
#   0.64387892  0.72318727  0.65826224  1.45558263  0.32763054]
#  ===================================
# Plot saved to plots/signal/2017/ST_2017.pdf

# %%
variable = "ST_full" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [8.56130431 6.5206742  4.49477779 3.56974381 2.73956577 1.86927882
#  1.69321356]
#  Error: [2.35544984 2.37004167 1.25342546 0.94237556 0.73292569 0.60139386
#  0.30874118]
#  ===================================
# Plot saved to plots/signal/2017/ST_full_2017.pdf

# %%
variable = "jet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400, 500, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [2.2214672  2.11573295 2.68756373 1.53010574 2.96448544 4.03968619
#  2.5594089  2.5234366  2.84842819 1.92736903 1.65129819 1.7800704 ]
#  Error: [0.57784764 0.9015086  1.10405732 0.90190196 1.07126136 1.72965234
#  0.78417689 0.88970386 0.95036936 0.66987004 0.64308105 0.71275083]
#  ===================================
# Plot saved to plots/signal/2017/jet_pt_2017.pdf

# %%
variable = "bjet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [3.89078584 3.28967664 4.69367528 3.22488521 3.7562799  4.01644519
#  3.52287366 1.86744461 1.99156131 2.9458873 ]
#  Error: [0.91830129 1.01162878 1.69707348 1.25652797 0.8846824  1.22304993
#  1.19001869 0.71898815 0.86744562 0.96632696]
#  ===================================
# Plot saved to plots/signal/2017/bjet_pt_2017.pdf

# %%
variable = "lepton_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 7.95878583  2.04751033  5.13582504  3.48407017  3.28888948  2.27063858
#   3.16219341 10.79196765  3.88268293 65.04972887  2.88425309  1.82397328
#   2.33365063  2.10385621  8.45405308  6.21073298  2.7533112   3.6900311
#   3.3183464   2.20712135  7.42331906  3.41442763  2.12851958  4.15174847
#   1.775146    6.47500945 12.79370001  1.70240076  2.42535706  1.78367003
#   5.59373019  6.43327918]
#  Error: [  7.11724522   0.95803571   4.11306161   1.65381038   1.87417651
#    1.02433272   1.74626734  17.30921876   2.62434848 400.69637018
#    1.71159445   1.04183141   0.94722128   1.03725983   8.550532
#    4.85590944   1.38663318   4.19037122   1.59431809   1.06763996
#    7.02698544   1.49820903   1.15599256   2.57333678   0.93456804
#    3.81919336  17.33444029   0.91602583   1.38139302   0.76314058
#    4.29034018   5.5276014 ]
#  ===================================
# Plot saved to plots/signal/2017/lepton_phi_2017.pdf

# %%
variable = "bjet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 2.99651247  1.77278178  3.95556911  3.35658012  3.66064204  2.01409285
#   8.48023479  3.10361471  2.22182324  1.56694862  5.28338724  2.70913308
#  12.72849857  2.64547815  2.97473722  3.24977692  3.13416027 21.366576
#   5.94786548  2.48758876  2.13646859 11.34867698 10.79311024  4.63758
#   2.50548891  4.83539603  2.56224024  3.3308349   3.09962655  2.54343049
#  15.72806421  2.16828384]
#  Error: [ 1.71065007  0.77269244  1.87348477  3.44067307  2.39447803  0.94294734
#  10.3295309   3.12542725  1.73442348  0.78480906  3.9310187   1.34658559
#  22.08479731  1.56601279  1.35103389  1.38474188  1.58057744 49.20074384
#   4.5905076   1.59741778  1.16935611 13.93422467 16.71267589  2.93804403
#   1.17761983  3.22510788  0.98669077  1.1086847   1.03963686  1.30218314
#  26.88176797  4.39308556]
#  ===================================
# Plot saved to plots/signal/2017/bjet_phi_2017.pdf

# %%
variable = "met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 7.00975429 10.38263762  3.63461177  2.39372839  2.73674066  3.35492386
#   5.39661041  7.30592213  5.77504579  1.6004714  25.86186846  2.62867549
#   8.7313026   1.36031103  2.03639575  2.78383867  4.28187187 10.55915187
#   4.59140899  3.53483023  8.94300905  2.29124451 78.55933651  1.94216782
#   2.71743146  3.74662442  2.2078078   2.09805917  1.83851427 12.73940559
#   5.67404698  2.41579461]
#  Error: [7.39560715e+00 8.29248177e+00 1.59706795e+00 1.15545656e+00
#  1.29777880e+00 1.72892484e+00 3.48622036e+00 8.63397146e+00
#  4.79304323e+00 8.07540478e-01 8.09740993e+01 1.16107602e+00
#  9.07825233e+00 8.88574161e-01 1.09877954e+00 1.36416896e+00
#  3.86143925e+00 2.12654891e+01 3.39212565e+00 1.54208880e+00
#  9.08486104e+00 1.50011891e+00 8.95914406e+02 8.67813449e-01
#  2.16982611e+00 3.16620023e+00 8.99878816e-01 6.43035560e-01
#  6.07746581e-01 1.88188872e+01 3.80176208e+00 1.46443629e+00]
#  ===================================
# Plot saved to plots/signal/2017/met_phi_2017.pdf

# %%
variable = "jet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 1.84070173  1.37074036  2.7964927   3.3738141   7.11982221  3.01318772
#   3.85810948  2.28734354  3.23790253  8.1238574   1.78818709  1.78503816
#   1.75738113  3.80831435  3.41104789  1.18626642  1.12413008  3.67280463
#   2.47833176  0.31604085 10.0006993   4.10707686  3.64117596  7.6322796
#   2.123879    1.72688749  2.39856481  2.22199326  1.57891634  2.32936204
#   0.29689898  1.42013911]
#  Error: [ 1.34706834  0.78556882  1.69272899  1.86643785 11.35962674  1.43317039
#   2.95374191  0.96026858  1.85505609  9.34713314  0.91773912  2.0176823
#   1.17312894  2.49566341  2.61741941  0.62006985  0.67451274  2.58842714
#   1.24718392  0.37646482  9.21705017  2.60328524  2.39411022  9.37320918
#   1.52612579  0.92410832  1.73181609  1.30605393  1.0856027   1.60617908
#   0.70358426  3.16589535]
#  ===================================
# Plot saved to plots/signal/2017/jet_phi_2017.pdf

# %%
variable = "recoil_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 7.00975429 10.38263762  3.63461177  2.39372839  2.73674066  3.35492386
#   5.39661041  7.30592213  5.77504579  1.6004714  25.86186846  2.62867549
#   8.7313026   1.36031103  2.03639575  2.78383867  4.28187187 10.55915187
#   4.59140899  3.53483023  8.94300905  2.29124451 78.55933651  1.94216782
#   2.71743146  3.74662442  2.2078078   2.09805917  1.83851427 12.73940559
#   5.67404698  2.41579461]
#  Error: [7.39560715e+00 8.29248177e+00 1.59706795e+00 1.15545656e+00
#  1.29777880e+00 1.72892484e+00 3.48622036e+00 8.63397146e+00
#  4.79304323e+00 8.07540478e-01 8.09740993e+01 1.16107602e+00
#  9.07825233e+00 8.88574161e-01 1.09877954e+00 1.36416896e+00
#  3.86143925e+00 2.12654891e+01 3.39212565e+00 1.54208880e+00
#  9.08486104e+00 1.50011891e+00 8.95914406e+02 8.67813449e-01
#  2.16982611e+00 3.16620023e+00 8.99878816e-01 6.43035560e-01
#  6.07746581e-01 1.88188872e+01 3.80176208e+00 1.46443629e+00]
#  ===================================
# Plot saved to plots/signal/2017/recoil_phi_2017.pdf

# %%
variable = "lepton_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [  7.60422625   5.48545317   2.68482133   1.76569347   3.85390623
#    3.65463448   3.13672896   3.57339284   4.79750269   3.21211055
#    4.74504719   2.5367652    2.91125409   9.95643559   1.86316482
#  111.68422241   2.87149391   3.68601779   1.90700455   4.27355575
#    1.50746682   2.34778331   5.04004295   7.90080574]
#  Error: [5.27669469e+00 2.32163146e+00 1.47651119e+00 8.05902658e-01
#  2.05686774e+00 1.34586012e+00 1.46852438e+00 1.35436024e+00
#  2.95491135e+00 1.76540390e+00 2.33427796e+00 1.15113448e+00
#  1.43356896e+00 1.04680217e+01 1.01726051e+00 1.61665794e+03
#  1.23881269e+00 1.52854109e+00 7.63212278e-01 2.24352718e+00
#  7.12650515e-01 8.36039778e-01 2.32960487e+00 8.10539345e+00]
#  ===================================
# Plot saved to plots/signal/2017/lepton_eta_2017.pdf

# %%
variable = "bjet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [2.86553452 5.76186182 3.945405   4.20203733 1.96764911 3.6976855
#  5.2246997  4.05020869 5.69470494 3.44023628 2.2262585  3.93196834
#  2.40275904 5.13386432 2.20632302 4.78518764 5.12084738 2.56456141
#  2.26515958 3.49112516 3.17887512 2.86010769 2.98375658 6.42080522]
#  Error: [2.36996274 3.72798458 1.84761374 2.22490993 1.16314818 1.8545848
#  3.00634201 1.8428501  3.88958591 1.23145492 0.68345196 2.44198734
#  1.06965648 2.72355475 0.84258386 2.54298812 2.32352844 1.12990034
#  1.2818612  1.78040463 1.33716466 1.36833228 2.05702987 8.73895585]
#  ===================================
# Plot saved to plots/signal/2017/bjet_eta_2017.pdf

# %%
variable = "jet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [2.14665974 2.33946802 1.58771032 4.74677398 2.23880311 4.68372259
#  4.40172805 3.06221019 1.28764176 3.02545307 1.2290051  1.7802719
#  2.91228675 2.02734534 0.86336702 2.07070509 2.06524195 1.75423405
#  3.25597732 6.04553775 4.23497463 4.7172178  1.81485058 3.30032578]
#  Error: [0.81331792 1.04166155 0.91275214 3.28512895 0.78752484 2.94429879
#  2.04861933 2.56334871 0.68539204 1.9847266  0.81041448 0.90728009
#  1.59870046 1.30583771 0.61061726 1.01443109 0.93802295 0.67819587
#  1.63724438 3.92053888 2.9479161  5.03386625 1.27692176 2.96088843]
#  ===================================
# Plot saved to plots/signal/2017/jet_eta_2017.pdf

# %%
variable = "njets_full"
binning = [2, 3, 4, 5, 6, 7, 8, 9, 10]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [7.28501549 1.93948857 1.45259844 0.66744711 0.56209754 0.
#  0.37841079 0.        ]
#  Error: [0.99380798 0.30606726 0.49288557 0.62287629 0.41218658 0.
#  0.55972041 0.        ]
#  ===================================
# Plot saved to plots/signal/2017/njets_full_2017.pdf

# %%
variable = "nmuons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [3.44926222 0.         0.         0.         0.        ]
#  Error: [0.27758827 0.         0.         0.         0.        ]
#  ===================================
# Plot saved to plots/signal/2017/nmuons_2017.pdf

# %%
variable = "nelectrons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [3.44926222 0.         0.         0.         0.        ]
#  Error: [0.27758827 0.         0.         0.         0.        ]
#  ===================================
# Plot saved to plots/signal/2017/nelectrons_2017.pdf

# %%
variable = "ntaus"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0


y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [0.         3.44926222 0.         0.         0.        ]
#  Error: [0.         0.27758827 0.         0.         0.        ]
#  ===================================
# Plot saved to plots/signal/2017/ntaus_2017.pdf

# %%
variable = "nbjets"
binning = [0, 1, 2, 3, 4]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [0.         3.44926222 0.         0.        ]
#  Error: [0.         0.27758827 0.         0.        ]
#  ===================================
# Plot saved to plots/signal/2017/nbjets_2017.pdf

# %%
variable = "njets"
binning = [0, 1, 2, 3, 4, 5, 6, 7, 8]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 300000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [0.         4.04807767 1.95637041 1.47892159 0.62270643 0.56965094
#  0.         0.28001548]
#  Error: [0.         0.60385539 0.30902374 0.50741517 0.58398913 0.41320874
#  0.         0.44053399]
#  ===================================
# Plot saved to plots/signal/2017/njets_2017.pdf

# %%
variable = "npvs"
binning = np.arange(6, 52 + 2, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.0001, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
#  ===================================
# QCD transfer factor:
#  Valor central: [ 0.          2.02942561  3.8055482   4.99495609  4.95478793  2.78872009
#   3.85424926  2.9945553   3.87603469  4.05996718  3.50736679  3.4779988
#   3.43447424  3.92449497  3.68826296  3.61194488  4.59291194  1.57909644
#   2.9202502   1.0963586   5.92178127 13.14128644  5.98889493]
#  Error: [ 0.          3.13920612  3.88723087  5.47092878  2.81763155  1.24054411
#   1.53625454  1.09690723  1.40423713  1.65183963  1.14600058  1.68886614
#   1.37085697  1.57540895  1.53885333  1.87437822  2.63997335  0.56334332
#   1.36756074  0.60323773  5.15763399 19.4166665   2.86520476]
#  ===================================
# Plot saved to plots/signal/2017/npvs_2017.pdf

# %% [markdown]
# # QCD shape

# %%
qcd_table = plotter.qcd_comparison(distribution = "lepton_met_mass", 
                                   binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300], 
                                   overflow = True, 
                                   underflow = True, 
                                   normalize= True,
                                   log_scale = True,
                                   y_range = (0.01, 1))
qcd_table

# %% [markdown]
# # Root

# %%
include_plots = True # Variable que nos permite ver los gráficos, si está en false generará unicamente el archivo root y no veremos nada

events, percentages = plotter.get_root_files(CR_name = "signal", with_plots = include_plots, distribution = "lepton_met_mass", binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300])
events
# Out:
# ⚠️ 'data' no encontrada. Creando ROOT con histograma vacío...
# png files have been stored in plots/signal/2017/root/png_files
# png files have been stored in plots/signal/2017/root/png_files

# %%
percentages

# %%
sorted_df = percentages["Total MC"].sort_values(by="Up (%)", ascending=False)
sorted_df

# %% [markdown]
# # Backup

# %%
pkls, jsons, norms, sumw = plotter.get_maps()

# %%
from src.utils_boost_weights import WeightPlotter  # tu archivo .py

year = "2016APV"
weight_case = "ISR_Zmumu_weight_FxFx" # top_boost_tau; ISR_Zmumu_weight_FxFx
json_path = f"jsons/corrections/{weight_case}/{weight_case}_{year}.json"
output_folder =  f"plots/{weight_case}"

plotter = WeightPlotter(year=year, weight_case=weight_case)
plotter.plot(json_path=json_path, output_file=f"{output_folder}/{weight_case}_{year}.pdf")
# Out:
# ✅ Gráfico guardado en plots/ISR_Zmumu_weight_FxFx/ISR_Zmumu_weight_FxFx_2016APV.pdf

# %%
import numpy as np
from src.Plotter import Plotter
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# --------------------
# General configs
# --------------------
year = "2017"
case = "with_boost"   # with_boost: top boost; without_boost: No top boost
samples_folder = f"../New_results/top_tagger/{case}/{year}"
output_folder = f"plots/tt/{year}"
lepton_flavor = "tau"
control_region = "tt"

# 2016APV and 2016 combined
combined_2016 = True

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False

# ---------------------
# Include signal samples
# --------------------
include_signal_samples = False


# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True
stadistical_error_using = "cutflow_raw"  #  Cutflow_raw: Eventos sin pesar.
normalized_to = "sumw_case_3"                   # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw; sumw_case_1; sumw_case_1; sumw_case_3


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  control_region = control_region,                  
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  include_signal_samples = include_signal_samples,
                  
                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                 )
# Out:
# Samples directory set to: ../New_results/top_tagger/with_boost/2017
# Output directory set to: plots/tt/2017
# ROOT files directory set to: plots/tt/2017/root
# Reading files for 2016: pkl -> ../New_results/top_tagger/with_boost/2016/summary/pkl, json -> ../New_results/top_tagger/with_boost/2016/summary/metadata
#
#  MC estimation normalized to sumw_case_3
# Reading files for 2016APV: pkl -> ../New_results/top_tagger/with_boost/2016APV/summary/pkl, json -> ../New_results/top_tagger/with_boost/2016APV/summary/metadata
#
#  MC estimation normalized to sumw_case_3

# %% [markdown]
# ## Tables
#
# ## Stadistical error
#
# ### Binomial statistics:
#
# $\delta \varepsilon_{i} = \sqrt{\frac{\epsilon_{i}}{N_{tot}}(1 - \varepsilon_{i}})$
#
# $ N_{i} = L\times \sigma_{i} \times \epsilon_{i} \rightarrow \delta N_{i} = L \times \sigma_{i} \times \delta \varepsilon_{i}$
#
#
# ### Bayesian:
#
# In order to consider cases where the efficiency is close to 0 or 1 it is neccesary to use Bayesian statistics.
#
#
# #### Combination
#
# Finally, as the total number of expected events for each background is the combination of different types; for instance, TTToSemiLeptonic + TTToHadronic + TTTo2L2Nu = $tt$.
#
# $ N_{X} = \sum_{i} N_{X_{i}} \rightarrow \delta N_{X} = \sqrt{\sum_{i} \left(\delta N_{X_{i}}\right)^2} $
#
#
# ## Systematic error:

# %%
cutflow_table, error = plotter.get_table_cutflow(variation = "cutflow", combined_samples = True)
cutflow_table
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#                                               tt           SingleTop  \
# sumw                                 30171295.39         10907269.83
# goodvertex                    30171294.97 ± 0.54  10907269.44 ± 0.81
# Stitching                     30171294.97 ± 0.54  10907269.44 ± 0.81
# lumi                          30171294.97 ± 0.54  10907269.44 ± 0.81
# trigger_tau                  1960055.99 ± 508.70  281041.73 ± 262.81
# metfilters                   1956848.14 ± 508.27  280482.66 ± 262.54
# HEMCleaning                  1956848.14 ± 508.27  280482.66 ± 262.54
# electron_veto                1587768.55 ± 465.46  233239.35 ± 238.66
# muon_veto                     849505.21 ± 349.49  122587.33 ± 168.14
# one_tau                         53448.38 ± 87.68     7449.31 ± 47.90
# delta_phi_jet_met_0.7_False     43795.40 ± 79.28     6462.07 ± 44.37
# met_180                         13376.53 ± 46.12     2439.37 ± 28.09
# passing_top_tagger               3873.65 ± 24.63      444.27 ± 13.04
#
#                                                W+jets                 VV  \
# sumw                                    2357347511.50         4201430.10
# goodvertex                     2357342981.76 ± 216.00  4201428.84 ± 0.53
# Stitching                    2243408615.97 ± 29181.92  4201428.84 ± 0.53
# lumi                         2243408615.97 ± 29181.92  4201428.84 ± 0.53
# trigger_tau                      7199247.46 ± 2815.15   92794.37 ± 99.08
# metfilters                       7189725.40 ± 2813.80   92629.67 ± 98.99
# HEMCleaning                      7189725.40 ± 2813.80   92629.67 ± 98.99
# electron_veto                    6394122.62 ± 2621.25   79858.45 ± 92.42
# muon_veto                        3748415.75 ± 2060.49   51317.93 ± 75.51
# one_tau                            147587.70 ± 389.46    2050.90 ± 14.74
# delta_phi_jet_met_0.7_False        133373.56 ± 377.31    1833.81 ± 13.91
# met_180                             47397.71 ± 194.96      735.38 ± 8.74
# passing_top_tagger                     198.48 ± 11.16        4.92 ± 0.84
#
#                                      DrellYan+jets              Higgs  \
# sumw                                  977247340.00         1330797.81
# goodvertex                   977241056.05 ± 321.33  1330797.57 ± 5.67
# Stitching                    977241056.05 ± 321.33  1330797.57 ± 5.67
# lumi                         977241056.05 ± 321.33  1330797.57 ± 5.67
# trigger_tau                    627102.18 ± 2427.70  21118.16 ± 140.29
# metfilters                     625588.37 ± 2424.75  21075.35 ± 140.03
# HEMCleaning                    625588.37 ± 2424.75  21075.35 ± 140.03
# electron_veto                  605464.00 ± 2388.53  16984.00 ± 134.24
# muon_veto                      145713.01 ± 1257.57   9176.68 ± 107.02
# one_tau                           9577.68 ± 286.63     357.82 ± 16.18
# delta_phi_jet_met_0.7_False       7997.74 ± 260.19     287.24 ± 13.04
# met_180                           2016.97 ± 132.32       90.32 ± 5.29
# passing_top_tagger                   30.81 ± 12.80        0.11 ± 0.07
#
#                                                         QCD  \
# sumw                                      10030167623183.00
# goodvertex                   10030166553894.13 ± 1130320.68
# Stitching                    10030166553894.13 ± 1130320.68
# lumi                         10030166553894.13 ± 1130320.68
# trigger_tau                        12350884.93 ± 1544290.11
# metfilters                         11887643.13 ± 1544278.10
# HEMCleaning                        11887643.13 ± 1544278.10
# electron_veto                      11871633.60 ± 1544275.47
# muon_veto                          11709536.63 ± 1544246.28
# one_tau                                   8912.22 ± 1834.89
# delta_phi_jet_met_0.7_False                3701.98 ± 454.12
# met_180                                     678.28 ± 137.20
# passing_top_tagger                              8.76 ± 7.93
#
#                             Data (MET_2016, MET_2016APV)  \
# sumw                                        177315637.00
# goodvertex                                  174618375.00
# Stitching                                   174618375.00
# lumi                                        166694414.00
# trigger_tau                                  29525682.00
# metfilters                                   25378878.00
# HEMCleaning                                  25378878.00
# electron_veto                                24336449.00
# muon_veto                                    20912380.00
# one_tau                                        206444.00
# delta_phi_jet_met_0.7_False                    176911.00
# met_180                                         79512.00
# passing_top_tagger                               4536.00
#
#                                                       Total
# sumw                                      10033548828827.63
# goodvertex                   10033547748722.77 ± 1130320.74
# Stitching                    10033433814356.98 ± 1130697.36
# lumi                         10033433814356.98 ± 1130697.36
# trigger_tau                        22532244.82 ± 1544294.70
# metfilters                         22053992.72 ± 1544282.69
# HEMCleaning                        22053992.72 ± 1544282.69
# electron_veto                      20789070.57 ± 1544279.64
# muon_veto                          16636252.54 ± 1544248.22
# one_tau                                 229384.02 ± 1900.29
# delta_phi_jet_met_0.7_False              197451.78 ± 651.85
# met_180                                   66734.54 ± 278.14
# passing_top_tagger                          4561.00 ± 33.59

# %%
table_report, SF = plotter.get_table_report()
table_report
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
# Samples                         Events ± stat  Syst up  Syst down  \
# tt                            3873.65 ± 24.63   755.44     773.59
# SingleTop                      444.27 ± 13.04    79.34      80.49
# W+jets                         198.48 ± 11.16    38.77      38.80
# DrellYan+jets                   30.81 ± 12.80     5.91       4.72
# QCD                               8.76 ± 7.93     4.94       5.07
# VV                                4.92 ± 0.84     0.92       0.95
# Higgs                             0.11 ± 0.07     0.04       0.05
# Data (MET_2016, MET_2016APV)          4536.00     0.00       0.00
# Total bgr                     4561.00 ± 33.60   862.37     879.08
# Data/Total bgr                           0.99      NaN        NaN
# Rtt (tt)                        0.994 ± 0.009      NaN        NaN
#
# Samples                       Contribution (%)
# tt                                       84.93
# SingleTop                                 9.74
# W+jets                                    4.35
# DrellYan+jets                             0.68
# QCD                                       0.19
# VV                                        0.11
# Higgs                                     0.00
# Data (MET_2016, MET_2016APV)               NaN
# Total bgr                                  NaN
# Data/Total bgr                             NaN
# Rtt (tt)                                   NaN

# %% [markdown]
# ### Plot

# %%
variable = "lepton_met_mass" 
binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 600)
ratio_plot_limits = (0.5, 1.5)

histos,  group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['njets_no_top_tagger', 'lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2016']
# Plot saved to plots/tt/2017/lepton_met_mass_2016_full.pdf
#                                           $t\bar{t}$  \
# 0-20_     1132.70 ± 33.66 (Up: 216.90, Down: 223.20)
# 20-40_    1110.35 ± 33.32 (Up: 210.71, Down: 215.32)
# 40-60_     804.37 ± 28.36 (Up: 164.86, Down: 170.10)
# 60-80_       435.63 ± 20.87 (Up: 82.58, Down: 83.85)
# 80-100_      151.71 ± 12.32 (Up: 29.37, Down: 30.55)
# 100-120_       57.63 ± 7.59 (Up: 12.34, Down: 12.36)
# 120-150_       60.55 ± 7.78 (Up: 12.89, Down: 12.46)
# 150-200_       56.19 ± 7.50 (Up: 11.10, Down: 11.34)
# 200-300_       64.51 ± 8.03 (Up: 10.26, Down: 10.85)
# Total     3873.65 ± 62.24 (Up: 356.16, Down: 365.56)
#
#                                        Single Top  \
# 0-20_     149.79 ± 12.24 (Up: 24.02, Down: 25.22)
# 20-40_    136.15 ± 11.67 (Up: 21.87, Down: 21.74)
# 40-60_      89.56 ± 9.46 (Up: 14.29, Down: 14.53)
# 60-80_        40.97 ± 6.40 (Up: 7.46, Down: 7.82)
# 80-100_       10.96 ± 3.31 (Up: 3.38, Down: 3.76)
# 100-120_       5.21 ± 2.28 (Up: 0.91, Down: 1.02)
# 120-150_       4.00 ± 2.00 (Up: 0.90, Down: 0.84)
# 150-200_       4.25 ± 2.06 (Up: 0.40, Down: 1.91)
# 200-300_       3.39 ± 1.84 (Up: 0.90, Down: 1.08)
# Total     444.27 ± 21.08 (Up: 36.46, Down: 37.44)
#
#                                         WJetToLNu  \
# 0-20_       70.45 ± 8.39 (Up: 12.79, Down: 13.67)
# 20-40_        56.57 ± 7.52 (Up: 9.53, Down: 9.78)
# 40-60_        36.64 ± 6.05 (Up: 6.59, Down: 7.95)
# 60-80_        23.36 ± 4.83 (Up: 5.75, Down: 8.15)
# 80-100_        5.73 ± 2.39 (Up: 1.82, Down: 1.79)
# 100-120_       1.35 ± 1.16 (Up: 0.40, Down: 0.23)
# 120-150_       0.28 ± 0.53 (Up: 1.81, Down: 1.81)
# 150-200_       1.62 ± 1.27 (Up: 0.85, Down: 0.60)
# 200-300_       2.48 ± 1.57 (Up: 0.85, Down: 0.81)
# Total     198.48 ± 14.09 (Up: 18.42, Down: 20.49)
#
#                                      Diboson  \
# 0-20_     2.03 ± 1.43 (Up: 0.41, Down: 0.35)
# 20-40_    1.77 ± 1.33 (Up: 0.42, Down: 0.54)
# 40-60_    0.39 ± 0.63 (Up: 0.11, Down: 0.11)
# 60-80_    0.37 ± 0.61 (Up: 0.14, Down: 0.17)
# 80-100_   0.09 ± 0.30 (Up: 0.02, Down: 0.06)
# 100-120_  0.06 ± 0.25 (Up: 0.04, Down: 0.06)
# 120-150_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 150-200_  0.05 ± 0.23 (Up: 0.07, Down: 0.07)
# 200-300_  0.14 ± 0.38 (Up: 0.06, Down: 0.09)
# Total     4.92 ± 2.22 (Up: 0.62, Down: 0.69)
#
#                                   DYJetsToLNu  \
# 0-20_     17.53 ± 4.19 (Up: 2.84, Down: 6.08)
# 20-40_    10.05 ± 3.17 (Up: 5.05, Down: 4.52)
# 40-60_     0.92 ± 0.96 (Up: 3.17, Down: 3.18)
# 60-80_     1.95 ± 1.40 (Up: 0.30, Down: 0.79)
# 80-100_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 100-120_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 120-150_   0.35 ± 0.60 (Up: 0.17, Down: 0.28)
# 150-200_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 200-300_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# Total     30.81 ± 5.55 (Up: 6.61, Down: 8.26)
#
#                                        Higgs  \
# 0-20_     0.05 ± 0.22 (Up: 0.02, Down: 0.02)
# 20-40_    0.00 ± 0.00 (Up: 0.01, Down: 0.01)
# 40-60_    0.04 ± 0.21 (Up: 0.02, Down: 0.03)
# 60-80_    0.02 ± 0.14 (Up: 0.01, Down: 0.01)
# 80-100_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 100-120_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 120-150_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 200-300_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# Total     0.11 ± 0.33 (Up: 0.03, Down: 0.04)
#
#                                          QCD     Data  \
# 0-20_     3.78 ± 1.94 (Up: 0.94, Down: 1.72)     1344
# 20-40_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)     1226
# 40-60_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)      953
# 60-80_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)      521
# 80-100_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)      208
# 100-120_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)       72
# 120-150_  4.48 ± 2.12 (Up: 4.66, Down: 6.02)       76
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)       66
# 200-300_  0.49 ± 0.70 (Up: 0.07, Down: 0.28)       70
# Total     8.76 ± 2.96 (Up: 4.76, Down: 6.27)  4536.00
#
#                                             Total MC  Data / Total MC
# 0-20_     1376.34 ± 37.10 (Up: 218.62, Down: 225.13)             0.98
# 20-40_    1314.89 ± 36.26 (Up: 212.12, Down: 216.69)             0.93
# 40-60_     931.93 ± 30.53 (Up: 165.64, Down: 170.94)             1.02
# 60-80_       502.30 ± 22.41 (Up: 83.12, Down: 84.61)             1.04
# 80-100_      168.49 ± 12.98 (Up: 29.62, Down: 30.83)             1.23
# 100-120_       64.26 ± 8.02 (Up: 12.38, Down: 12.40)             1.12
# 120-150_       69.66 ± 8.35 (Up: 13.86, Down: 13.99)             1.09
# 150-200_       62.11 ± 7.88 (Up: 11.14, Down: 11.51)             1.06
# 200-300_       71.01 ± 8.43 (Up: 10.34, Down: 10.94)             0.99
# Total     4561.00 ± 67.53 (Up: 358.59, Down: 368.19)             0.99

# %%
variable = "lepton_pt" 
binning = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 250, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = SF

y_axis_range = (0.1, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "met" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 1000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "recoil_pt" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST_met" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 80)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST" 
binning =[100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 1000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST_full" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 1000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400, 500, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 1000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "bjet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400]


overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 2000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "bjet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "recoil_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "bjet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "njets_no_top_tagger"
binning = [0,1, 2, 3, 4]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "njets_full"
binning = [2, 3, 4, 5, 6, 7, 8, 9, 10]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nmuons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nelectrons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ntaus"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nbjets"
binning = [0, 1, 2, 3, 4]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "njets"
binning = [0, 1, 2, 3, 4, 5, 6, 7, 8]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "top_mrec"
binning = [100,140, 160, 180, 200, 220, 240, 260]

overflow = True
underflow = True

divided_GeV = True
log_scale = False

main_bgr = "tt"
sf_bgr = SF

y_axis_range = (0.1, 150)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "npvs"
binning = np.arange(6, 52 + 2, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 1000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %% [markdown]
# # 2D plots and weights

# %%
X_variable = "ST_met"
X_binning = [300, 400, 500, 600, 700, 800, 900,1000]

Y_variable = "njets_no_top_tagger"
Y_binning = [0,1, 2, 3, 4] 

df_2D_total = plotter.get_2D_plot_report(X_distribution = X_variable, X_binning = X_binning, 
                           Y_distribution = Y_variable, Y_binning = Y_binning, 
                           background = "total",  
                           include_overflow = overflow, include_underflow = underflow,
                           bin_values = True,
                          )

df_2D_data = plotter.get_2D_plot_report(X_distribution = X_variable, X_binning = X_binning, 
                           Y_distribution = Y_variable, Y_binning = Y_binning, 
                           background = "data", 
                           include_overflow = overflow, include_underflow = underflow,
                            bin_values = True,                                        
                          )

df_2D_tt = plotter.get_2D_plot_report(X_distribution = X_variable, X_binning = X_binning, 
                           Y_distribution = Y_variable, Y_binning = Y_binning, 
                           background = "tt", 
                           include_overflow = overflow, include_underflow = underflow,
                            bin_values = True,                                      
                          )

# %%
# El siguiente mapa 2D es ilustrativo
weights_range = (0.9, 1.1) # 0.85-1.10
filter_parameters = (0, 2, 1) # Min; Max, sigma
smoothed = False
df_2D_weights = plotter.get_2D_weights(df_total_bgr = df_2D_total, df_main_bgr = df_2D_tt, df_data = df_2D_data, range = weights_range, filter_parameters = filter_parameters, smoothed = smoothed)
df_2D_weights

# %% [markdown]
# # Root files

# %%
include_plots = False # Variable que nos permite ver los gráficos, si está en false generará unicamente el archivo root y no veremos nada

events, percentages = plotter.get_root_files(CR_name = "ttcr1", with_plots = include_plots, distribution = "lepton_met_mass", binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300])
events

# %%
percentages

# %%
sorted_df = percentages["Total MC"].sort_values(by="Up (%)", ascending=False)
sorted_df

# %% [markdown]
# # Auxiliar function: tt boost weights

# %%
import pandas as pd
import numpy as np

def merge_event_tables(df_total, df_tt, df_data):
    """
    Fusiona tres tablas 2D (total, tt, data) en una sola por columnas comunes distintas de 'events'.

    Args:
    df_total: DataFrame con columnas ['<bin1>', '<bin2>', 'events']
    df_tt:    DataFrame con columnas ['<bin1>', '<bin2>', 'events']
    df_data:  DataFrame con columnas ['<bin1>', '<bin2>', 'events']

    Returns:
        DataFrame combinado con columnas:
            ['<bin1>', '<bin2>', 'Total', 'MainBgr', 'Data']
    """
    # Detectar automáticamente las columnas de binning (todas menos 'events')
    bin_cols = [col for col in df_total.columns if col != "events"]
    
    # Renombrar columnas de eventos
    df_total_ren = df_total.rename(columns={"events": "Total"})
    df_tt_ren = df_tt.rename(columns={"events": "MainBgr"})
    df_data_ren = df_data.rename(columns={"events": "Data"})
    
    # Merge sucesivos usando las columnas detectadas
    merged = pd.merge(df_total_ren, df_tt_ren, on=bin_cols, how="outer")
    merged = pd.merge(merged, df_data_ren, on=bin_cols, how="outer")
    
    # Ordenar por binning si es posible
    merged.sort_values(by=bin_cols, inplace=True)
    merged.reset_index(drop=True, inplace=True)
    
    return merged

# %%
table = merge_event_tables(df_2D_total, df_2D_tt, df_2D_data)
pd.set_option("display.max_rows", None)     # Muestra todas las filas
pd.set_option("display.max_columns", None)  # Muestra todas las columnas
pd.set_option("display.width", None)        # Evita que se parta en varias líneas
pd.set_option("display.max_colwidth", None) # Muestra el contenido completo de las celdas

table

# %% [markdown]
# # Backup
#
#
# La función get_maps() esta definida por si se desea rastrear que se esta leyendo de los pkls y jsons.

# %%
pkls, jsons, norms, sumw = plotter.get_maps()

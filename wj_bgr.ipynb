# %%
import numpy as np
from src.Plotter import Plotter

# %%
# --------------------
# General configs
# --------------------
year = "2016APV"
samples_folder = f"../New_results/wplusjets/wjets/{year}" 
output_folder = f"plots/wj/{year}"
lepton_flavor = "tau"
control_region = "wjets"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False

# ---------------------
# Include signal samples
# --------------------
include_signal_samples = True


# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True

stadistical_error_using = "cutflow_raw"  #  Cutflow_raw: Eventos sin pesar.
normalized_to = "sumw_case_3"            # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw; sumw_case_1; sumw_case_1; sumw_case_3


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# -------------------------
#    QCD estimation
# -------------------------
activate_qcd_data_driven = True
cr_B_folder = f"../New_results/wplusjets/cr_b/{year}" 
cr_C_folder = f"../New_results/wplusjets/cr_c/{year}" 
cr_D_folder = f"../New_results/wplusjets/cr_d/{year}" 


qcd_ratio_integrated = False
qcd_shape = "cr_b"
qcd_ratio = ["cr_c", "cr_d"]   # cr_c/cr_d

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  control_region = control_region,
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  include_signal_samples = include_signal_samples,
                  
                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                  applied_data_driven = activate_qcd_data_driven,
                  cr_B_folder = cr_B_folder,
                  cr_C_folder = cr_C_folder,
                  cr_D_folder = cr_D_folder,

                  qcd_shape = qcd_shape,
                  qcd_ratio = qcd_ratio,   # cr_c/cr_d
                  qcd_ratio_integrated = qcd_ratio_integrated
                 )
# Out:
# Samples directory set to: ../New_results/wplusjets/wjets/2016APV
# Output directory set to: plots/wj/2016APV
# ROOT files directory set to: plots/wj/2016APV/root
#  Reading pkl files from: ../New_results/wplusjets/wjets/2016APV/summary/pkl
#  Reading json files from: ../New_results/wplusjets/wjets/2016APV/summary/metadata
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3
#
#  MC estimation normalized to sumw_case_3

# %% [markdown]
# # Cutflow

# %%
cutflow_table, error, qcd = plotter.get_table_cutflow(variation = "cutflow", combined_samples = True)
cutflow_table
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#
# 🔎 Revisando dataset tipo data: MET
#                                               tt           SingleTop  \
# sumw                                 16203886.87          5857663.50
# goodvertex                    16203886.45 ± 0.46   5857663.15 ± 0.61
# lumi                          16203886.45 ± 0.46   5857663.15 ± 0.61
# Stitching                     16203886.45 ± 0.46   5857663.15 ± 0.61
# trigger_tau                  1039376.69 ± 371.24  148775.39 ± 192.89
# metfilters                   1037604.63 ± 370.91  148458.40 ± 192.68
# electron_veto                 872347.26 ± 344.56  127220.96 ± 177.84
# muon_veto                     477745.30 ± 261.30   68494.91 ± 126.86
# bjet_veto                     150685.43 ± 149.30    29628.68 ± 83.49
# one_tau                          9275.10 ± 35.87     1671.74 ± 22.41
# delta_phi_jet_met_0.7_False      7464.09 ± 32.21     1457.31 ± 20.90
# met_180                          2324.01 ± 18.64      494.82 ± 12.52
# failing_top_tagger               2315.04 ± 18.60      493.92 ± 12.51
#
#                                                W+jets                 VV  \
# sumw                                    1265986607.83         2256345.00
# goodvertex                     1265983017.32 ± 167.55  2256343.86 ± 0.42
# lumi                           1265983017.32 ± 167.55  2256343.86 ± 0.42
# Stitching                    1203376423.30 ± 22089.24  2256343.86 ± 0.42
# trigger_tau                      3774741.31 ± 2003.62   48735.37 ± 71.22
# metfilters                       3769382.21 ± 2002.55   48645.12 ± 71.15
# electron_veto                    3397280.70 ± 1874.60   42696.93 ± 66.95
# muon_veto                        2020705.30 ± 1484.68   27628.20 ± 54.74
# bjet_veto                        1966727.19 ± 1472.75   25985.88 ± 52.80
# one_tau                             77386.81 ± 270.76    1058.06 ± 10.40
# delta_phi_jet_met_0.7_False         69818.56 ± 262.45      943.50 ± 9.81
# met_180                             24409.94 ± 135.59      370.41 ± 6.13
# failing_top_tagger                  24409.73 ± 135.59      370.41 ± 6.13
#
#                                      DrellYan+jets              Higgs  \
# sumw                                  524823000.00          714694.50
# goodvertex                   524817972.99 ± 245.57   714694.32 ± 5.41
# lumi                         524817972.99 ± 245.57   714694.32 ± 5.41
# Stitching                    524817972.99 ± 245.57   714694.32 ± 5.41
# trigger_tau                    326353.39 ± 1696.07  11169.31 ± 121.13
# metfilters                     325559.67 ± 1693.89  11140.29 ± 120.85
# electron_veto                  316176.09 ± 1671.75   9278.89 ± 117.20
# muon_veto                        78248.03 ± 894.97    5068.34 ± 93.65
# bjet_veto                        74901.53 ± 877.24    4829.04 ± 90.45
# one_tau                           5044.45 ± 194.83     183.04 ± 12.24
# delta_phi_jet_met_0.7_False       4192.42 ± 176.85     157.32 ± 11.02
# met_180                            1081.92 ± 89.05       48.67 ± 3.77
# failing_top_tagger                 1081.92 ± 89.05       48.67 ± 3.77
#
#                                Data (MET)                     Total
# sumw                         109184771.00             1815842197.70
# goodvertex                   107437405.00    1815833578.10 ± 297.34
# lumi                         102521086.00    1815833578.10 ± 297.34
# Stitching                    102521086.00  1753226984.08 ± 22090.60
# trigger_tau                   15608556.00      5349151.46 ± 2661.94
# metfilters                    13007401.00      5340790.31 ± 2659.67
# electron_veto                 12535965.00      4765000.82 ± 2545.08
# muon_veto                     10744819.00      2677890.07 ± 1761.07
# bjet_veto                      9052426.00      2252757.74 ± 1725.91
# one_tau                          90604.00         94619.20 ± 336.63
# delta_phi_jet_met_0.7_False      77851.00         84033.20 ± 319.14
# met_180                          35021.00         28729.77 ± 163.92
# failing_top_tagger               35006.00         28719.69 ± 163.91

# %%
qcd
# Out:
#                                              QCD cr_b  \
# Cut
# sumw
# goodvertex                  -1708396186.27 ± 10369.47
# lumi                        -1713312505.27 ± 10129.63
# Stitching                   -1650705898.98 ± 24300.53
# trigger_tau                     10259404.93 ± 4763.87
# metfilters                       7666610.95 ± 4481.21
# electron_veto                    7770963.99 ± 4360.43
# muon_veto                        8066927.64 ± 3721.05
# bjet_veto                        6799666.23 ± 3468.60
# one_tau                             -4015.66 ± 451.58
# delta_phi_jet_met_0.7_True           2168.52 ± 156.77
# met_180                               1414.56 ± 92.54
# failing_top_tagger                    1410.72 ± 92.50
#
#                                              QCD cr_c  \
# Cut
# sumw
# goodvertex                  -1708396173.15 ± 10369.46
# lumi                        -1713312492.15 ± 10129.63
# Stitching                   -1650687175.30 ± 24291.50
# trigger_tau                     10259779.30 ± 4762.62
# metfilters                       7666985.59 ± 4479.88
# electron_veto                    7771118.83 ± 4359.17
# muon_veto                        8066024.78 ± 3720.40
# bjet_veto                        6799067.18 ± 3467.93
# one_tau                             19238.53 ± 321.37
# delta_phi_jet_met_0.7_True          11242.98 ± 291.19
# met_180                              5247.56 ± 156.21
# failing_top_tagger                   5244.15 ± 156.18
#
#                                              QCD cr_d      Ratio (X/Y)  \
# Cut
# sumw                                                   0.0000 ± 0.0000
# goodvertex                  -1708396166.92 ± 10369.46  1.0000 ± 0.0000
# lumi                        -1713312485.92 ± 10129.63  1.0000 ± 0.0000
# Stitching                   -1650687175.14 ± 24291.50  1.0000 ± 0.0000
# trigger_tau                     10259780.35 ± 4762.62  1.0000 ± 0.0007
# metfilters                       7666986.68 ± 4479.88  1.0000 ± 0.0008
# electron_veto                    7771119.45 ± 4359.17  1.0000 ± 0.0008
# muon_veto                        8066026.12 ± 3720.40  1.0000 ± 0.0007
# bjet_veto                        6799067.94 ± 3467.93  1.0000 ± 0.0007
# one_tau                             19238.59 ± 321.37  1.0000 ± 0.0236
# delta_phi_jet_met_0.7_True           7998.83 ± 137.06  1.4056 ± 0.0437
# met_180                               1833.03 ± 73.14  2.8628 ± 0.1425
# failing_top_tagger                    1829.05 ± 73.10  2.8671 ± 0.1429
#
#                                         QCD Estimated
# Cut
# sumw                                      0.00 ± 0.00
# goodvertex                  -1708396192.50 ± 17960.44
# lumi                        -1713312511.50 ± 17545.03
# Stitching                   -1650705899.14 ± 42079.64
# trigger_tau                     10259403.88 ± 8249.62
# metfilters                       7666609.86 ± 7759.89
# electron_veto                    7770963.37 ± 7550.93
# muon_veto                        8066926.30 ± 6444.78
# bjet_veto                        6799665.47 ± 6007.37
# one_tau                             -4015.65 ± 461.44
# delta_phi_jet_met_0.7_True           3048.02 ± 239.82
# met_180                              4049.57 ± 332.90
# failing_top_tagger                   4044.74 ± 333.13

# %% [markdown]
# # Table report

# %%
table_report, SF = plotter.get_table_report()
table_report
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#
# 🔎 Revisando dataset tipo data: MET
#                        Events ± stat  Syst up  Syst down  Contribution (%)
# W+jets             24409.73 ± 135.59  5026.16    5227.05             74.50
# QCD (Data-driven)   4044.74 ± 333.13  2105.58    2196.89             12.34
# tt                   2315.04 ± 18.60   479.80     484.75              7.07
# DrellYan+jets        1081.92 ± 89.05   232.63     239.23              3.30
# SingleTop             493.92 ± 12.51   130.65     131.97              1.51
# VV                     370.41 ± 6.13    59.92      61.05              1.13
# Higgs                   48.67 ± 3.77    61.08      61.12              0.15
# QCD Ratio (X/Y)        2.867 ± 0.143      NaN        NaN               NaN
# Data (MET)                  35006.00     0.00       0.00               NaN
# Total bgr          32764.43 ± 371.27  5871.66    6066.26               NaN
# Data/Total bgr                  1.07      NaN        NaN               NaN
# Rtt (W+jets)           1.092 ± 0.015      NaN        NaN               NaN

# %% [markdown]
# # Plot

# %%
variable = "lepton_met_mass" 
binning =  [0, 20, 40, 60, 80, 100, 120, 150, 200, 300]
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "wj"
sf_bgr = SF

y_axis_range = (0.1, 50000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2016APV']
#  ===================================
# QCD transfer factor:
#  Valor central: [5.08345183 2.43097782 3.08462757 1.92754701 2.04197775 1.89500425
#  2.73654296 2.25532323 3.65306005]
#  Error: [1.00055031 0.58226093 1.26041863 0.464732   0.35721253 0.25486838
#  0.24584883 0.19836737 0.28783792]
#  ===================================
# Plot saved to plots/wj/2016APV/lepton_met_mass_2016APV.pdf
#                                           $t\bar{t}$  \
# 0-20_      620.36 ± 24.91 (Up: 122.36, Down: 123.71)
# 20-40_     594.02 ± 24.37 (Up: 119.77, Down: 122.12)
# 40-60_       460.06 ± 21.45 (Up: 93.66, Down: 93.74)
# 60-80_       247.46 ± 15.73 (Up: 52.16, Down: 52.92)
# 80-100_      100.64 ± 10.03 (Up: 18.79, Down: 18.72)
# 100-120_       50.65 ± 7.12 (Up: 11.95, Down: 12.10)
# 120-150_       59.30 ± 7.70 (Up: 19.09, Down: 19.50)
# 150-200_       75.82 ± 8.71 (Up: 15.99, Down: 16.07)
# 200-300_     106.71 ± 10.33 (Up: 18.15, Down: 18.43)
# Total     2315.03 ± 48.11 (Up: 205.56, Down: 208.04)
#
#                                        Single Top  \
# 0-20_     133.56 ± 11.56 (Up: 23.47, Down: 23.49)
# 20-40_    128.05 ± 11.32 (Up: 30.94, Down: 36.69)
# 40-60_    104.49 ± 10.22 (Up: 25.75, Down: 25.32)
# 60-80_      58.99 ± 7.68 (Up: 13.92, Down: 14.23)
# 80-100_       22.17 ± 4.71 (Up: 4.84, Down: 5.14)
# 100-120_       7.17 ± 2.68 (Up: 3.33, Down: 3.77)
# 120-150_       9.36 ± 3.06 (Up: 1.27, Down: 1.87)
# 150-200_       9.36 ± 3.06 (Up: 2.70, Down: 2.98)
# 200-300_      20.78 ± 4.56 (Up: 4.03, Down: 3.88)
# Total     493.92 ± 22.22 (Up: 49.25, Down: 53.00)
#
#                                                WJetToLNu  \
# 0-20_       8749.57 ± 93.54 (Up: 1535.02, Down: 1610.98)
# 20-40_      7422.38 ± 86.15 (Up: 1260.60, Down: 1313.02)
# 40-60_       5434.40 ± 73.72 (Up: 983.98, Down: 1031.52)
# 60-80_        2735.38 ± 52.30 (Up: 495.36, Down: 514.23)
# 80-100_        753.82 ± 27.46 (Up: 124.13, Down: 130.38)
# 100-120_         238.19 ± 15.43 (Up: 51.04, Down: 54.90)
# 120-150_         236.72 ± 15.39 (Up: 37.98, Down: 40.94)
# 150-200_         208.03 ± 14.42 (Up: 46.14, Down: 48.00)
# 200-300_       873.98 ± 29.56 (Up: 195.00, Down: 210.29)
# Total     26652.47 ± 163.26 (Up: 2284.42, Down: 2390.81)
#
#                                           Diboson  \
# 0-20_     104.95 ± 10.24 (Up: 17.05, Down: 17.72)
# 20-40_      92.61 ± 9.62 (Up: 14.31, Down: 14.53)
# 40-60_      63.76 ± 7.98 (Up: 11.44, Down: 12.18)
# 60-80_        36.62 ± 6.05 (Up: 5.82, Down: 5.74)
# 80-100_       12.49 ± 3.53 (Up: 1.77, Down: 1.88)
# 100-120_       6.74 ± 2.60 (Up: 1.36, Down: 1.44)
# 120-150_       8.38 ± 2.89 (Up: 1.97, Down: 2.06)
# 150-200_      10.93 ± 3.31 (Up: 2.15, Down: 2.43)
# 200-300_      33.93 ± 5.82 (Up: 4.80, Down: 4.46)
# Total     370.41 ± 19.25 (Up: 26.40, Down: 27.24)
#
#                                          DYJetsToLNu  \
# 0-20_      472.44 ± 21.74 (Up: 118.26, Down: 119.99)
# 20-40_       268.66 ± 16.39 (Up: 51.84, Down: 55.14)
# 40-60_       127.17 ± 11.28 (Up: 29.31, Down: 27.92)
# 60-80_         84.96 ± 9.22 (Up: 21.22, Down: 22.14)
# 80-100_          33.37 ± 5.78 (Up: 9.20, Down: 9.40)
# 100-120_          1.43 ± 1.20 (Up: 4.91, Down: 7.76)
# 120-150_         19.97 ± 4.47 (Up: 5.04, Down: 5.66)
# 150-200_         12.04 ± 3.47 (Up: 3.27, Down: 2.73)
# 200-300_       61.88 ± 7.87 (Up: 21.00, Down: 21.78)
# Total     1081.92 ± 32.89 (Up: 136.26, Down: 139.17)
#
#                                           Higgs      Data  \
# 0-20_     12.03 ± 3.47 (Up: 11.93, Down: 11.94)     10642
# 20-40_    16.75 ± 4.09 (Up: 13.99, Down: 14.06)      8760
# 40-60_       9.45 ± 3.07 (Up: 8.69, Down: 8.71)      6714
# 60-80_       6.16 ± 2.48 (Up: 5.43, Down: 5.42)      3751
# 80-100_      2.63 ± 1.62 (Up: 2.34, Down: 2.35)      1262
# 100-120_     0.60 ± 0.77 (Up: 0.55, Down: 0.55)       541
# 120-150_     0.38 ± 0.61 (Up: 0.23, Down: 0.25)       621
# 150-200_     0.15 ± 0.39 (Up: 0.09, Down: 0.09)       612
# 200-300_     0.52 ± 0.72 (Up: 0.87, Down: 0.87)      2103
# Total     48.67 ± 6.98 (Up: 21.21, Down: 21.26)  35006.00
#
#                                                    QCD  \
# 0-20_      902.78 ± 295.55 (Up: 596.56, Down: 1009.60)
# 20-40_      520.08 ± 163.77 (Up: 247.28, Down: 403.51)
# 40-60_      643.66 ± 290.06 (Up: 243.99, Down: 499.02)
# 60-80_        317.79 ± 96.51 (Up: 82.02, Down: 167.20)
# 80-100_        210.73 ± 55.33 (Up: 30.29, Down: 52.11)
# 100-120_       143.80 ± 32.24 (Up: 10.77, Down: 23.92)
# 120-150_       331.59 ± 51.52 (Up: 13.57, Down: 29.72)
# 150-200_       234.53 ± 40.13 (Up: 12.89, Down: 20.72)
# 200-300_     881.92 ± 111.47 (Up: 71.32, Down: 134.58)
# Total     4186.87 ± 477.92 (Up: 699.82, Down: 1217.29)
#
#                                                 Total MC  Data / Total MC
# 0-20_     10995.69 ± 312.16 (Up: 1655.93, Down: 1909.25)             0.97
# 20-40_     9042.56 ± 188.00 (Up: 1291.76, Down: 1380.78)             0.97
# 40-60_     6843.01 ± 300.56 (Up: 1018.94, Down: 1150.43)             0.98
# 60-80_       3487.36 ± 111.73 (Up: 505.51, Down: 544.00)             1.08
# 80-100_       1135.83 ± 63.14 (Up: 129.60, Down: 142.08)             1.11
# 100-120_         448.58 ± 36.66 (Up: 53.86, Down: 61.72)             1.21
# 120-150_         665.70 ± 54.67 (Up: 44.97, Down: 54.58)             0.93
# 150-200_         550.86 ± 43.89 (Up: 50.73, Down: 54.90)             1.11
# 200-300_     1979.72 ± 116.29 (Up: 209.58, Down: 251.36)             1.06
# Total     35149.30 ± 509.29 (Up: 2402.65, Down: 2695.25)             1.00

# %%
variable = "lepton_pt" 
binning = [0, 50, 100, 150, 200, 300] 
overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "met" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 2000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "recoil_pt" 
binning = [180, 200, 250, 300, 350, 400, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST_met" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST" 
binning =[100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ST_full" 
binning =[300, 400, 500, 600, 700, 800, 900,  1000]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_pt" 
binning =[20, 40, 60, 80, 100, 150, 200, 250, 300, 350, 400, 500, 600]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 10000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "met_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "recoil_phi" 
binning = np.arange(-np.pi, np.pi + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0


y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "lepton_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "jet_eta" 
binning = np.arange(-2.4, 2.4 + 0.2, 0.2)
binning = np.round(binning, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "njets_full"
binning = [2, 3, 4, 5, 6, 7, 8, 9, 10]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nmuons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nelectrons"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0


y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "ntaus"
binning = [0, 1, 2, 3, 4, 5]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100000)
ratio_plot_limits = (0.5, 1.5)

y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "nbjets"
binning = [0, 1, 2, 3, 4]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "njets"
binning = [0, 1, 2, 3, 4, 5, 6, 7, 8]

overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 8000000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %%
variable = "npvs"
binning = np.arange(6, 52 + 2, 2)


overflow = True
underflow = True

divided_GeV = False
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 500000)
ratio_plot_limits = (0.5, 1.5)

histos, group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()

# %% [markdown]
# # QCD shape

# %%
qcd_table = plotter.qcd_comparison(distribution = "lepton_met_mass", 
                                   binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300], 
                                   overflow = True, 
                                   underflow = True, 
                                   normalize= False,
                                   log_scale = True,
                                   y_range = (0.01, 1000000))
qcd_table

# %% [markdown]
# # Root files

# %%
include_plots = False # Ver los plots de cada background con sus variaciones

events, percentages = plotter.get_root_files(CR_name = "wjcr1", with_plots = include_plots, distribution = "lepton_met_mass", binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300])
events

# %%
percentages

# %%
sorted_df = percentages["Total MC"].sort_values(by="Up (%)", ascending=False)
sorted_df

# %% [markdown]
# # Backup

# %%
pkls, jsons, norms, sumw = plotter.get_maps()

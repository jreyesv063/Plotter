# %%
import numpy as np
from src.Plotter import Plotter
# Out:
# Welcome to JupyROOT 6.30/04

# %%
# --------------------
# General configs
# --------------------
year = "2017"
case = "trigger_weights"   # no_weights  trigger_weights;  weighted_ISR
cr = "d"  # "b"; "c"; "d"
samples_folder = f"/eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_{case}/cr_{cr}/{year}" 
output_folder = f"plots/qcd/cr_{cr}/{case}/{year}"
lepton_flavor = "tau"
control_region = "qcd"

# 2016APV and 2016 combined
combined_2016 = False

# ---------------------
#  pkl and json files
# --------------------
merge_jsons_and_pkls = False

# -------------------------
# Stadistical/ Systematic error 
#         and
#  Normalization: xsec*Lumi
# -------------------------
systematic_error = True

stadistical_error_using = "cutflow_raw" #  Cutflow_raw: Eventos sin pesar.
normalized_to = "sumw_case_3"                  # Se puede normalizar a eventos no pesados "raw_initial_nevents" o pesados "sumw; sumw_case_1; sumw_case_1; sumw_case_3


# --------------------------
#    Create root files
# --------------------------
root_files = True
root_files_folder = f"{output_folder}/root"

# %%
# Creating a Plotter object
plotter = Plotter(year = year, 
                  samples_folder = samples_folder,
                  output_folder = output_folder,
                  lepton_flavor = lepton_flavor,
                  control_region = control_region,                      
                  
                  combined_2016 = combined_2016,
                  
                  merge_samples = merge_jsons_and_pkls,

                  systematic_error = systematic_error,
                  
                  normalized_to = normalized_to,
                  stadistical_error_using = stadistical_error_using,
                  
                  created_root_files = root_files,
                  root_files_folder = root_files_folder,

                 )
# Out:
# Samples directory set to: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_trigger_weights/cr_d/2017
# Output directory set to: plots/qcd/cr_d/trigger_weights/2017
# ROOT files directory set to: plots/qcd/cr_d/trigger_weights/2017/root
#  Reading pkl files from: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_trigger_weights/cr_d/2017/summary/pkl
#  Reading json files from: /eos/user/f/florez/WprimePlusB_OutputFiles/Last_results/qcd_hadronic_trigger_weights/cr_d/2017/summary/metadata
#
#  MC estimation normalized to sumw_case_3

# %% [markdown]
# # Cutflow

# %%
cutflow_table, error = plotter.get_table_cutflow(variation = "cutflow", combined_samples = True)
cutflow_table
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#
# 🔎 Revisando dataset tipo data: MET
#                                              tt           SingleTop  \
# sumw                                34427438.20         12460301.64
# goodvertex                   34427438.19 ± 0.12  12460301.42 ± 0.59
# lumi                         34427438.19 ± 0.12  12460301.42 ± 0.59
# Stitching                    34427438.19 ± 0.12  12460301.42 ± 0.59
# trigger_tau                 2062458.39 ± 345.16  316587.80 ± 280.44
# metfilters                  2059198.21 ± 344.86  315940.25 ± 280.13
# electron_veto               1716762.94 ± 319.42  269361.69 ± 257.02
# muon_veto                    925027.77 ± 241.62  144643.77 ± 182.57
# one_tau                        28154.39 ± 42.03     3521.46 ± 31.56
# one_bjet                       13844.03 ± 29.52     1632.15 ± 21.89
# delta_phi_jet_met_0.7_True      3145.52 ± 14.27       284.60 ± 9.56
# met_180                          1004.31 ± 8.34       106.80 ± 6.01
# failing_top_tagger                465.95 ± 5.70        71.46 ± 4.78
#
#                                               W+jets                  VV  \
# sumw                                   2692806043.86          4799650.80
# goodvertex                    2692804412.81 ± 206.86   4799650.65 ± 0.45
# lumi                          2692804412.81 ± 206.86   4799650.65 ± 0.45
# Stitching                   2563327543.88 ± 47482.15   4799650.65 ± 0.45
# trigger_tau                     7914236.00 ± 3875.43  100438.41 ± 148.41
# metfilters                      7904025.11 ± 3872.68  100260.12 ± 148.26
# electron_veto                   7094124.47 ± 3565.61   87161.62 ± 137.83
# muon_veto                       4216847.08 ± 3118.24   55777.48 ± 109.75
# one_tau                            62091.98 ± 292.04      983.22 ± 14.77
# one_bjet                             1343.59 ± 31.28        36.49 ± 2.93
# delta_phi_jet_met_0.7_True            232.58 ± 11.39         5.20 ± 1.23
# met_180                                 83.17 ± 5.99         2.03 ± 0.81
# failing_top_tagger                      64.79 ± 5.23         2.03 ± 0.81
#
#                                      DrellYan+jets              Higgs  \
# sumw                                 1116392720.00         1520283.48
# goodvertex                  1116390647.41 ± 208.07  1520283.44 ± 5.57
# lumi                        1116390647.41 ± 208.07  1520283.44 ± 5.57
# Stitching                   1116390647.41 ± 208.07  1520283.44 ± 5.57
# trigger_tau                    722175.46 ± 2570.07  25879.85 ± 194.19
# metfilters                     720197.42 ± 2566.26  25838.72 ± 193.93
# electron_veto                  696319.33 ± 2522.53  21478.44 ± 186.67
# muon_veto                      173035.17 ± 1385.38  11787.70 ± 153.51
# one_tau                           3996.42 ± 186.84     262.98 ± 20.91
# one_bjet                            132.60 ± 41.09        4.43 ± 1.34
# delta_phi_jet_met_0.7_True           54.70 ± 18.47        1.42 ± 1.14
# met_180                               12.45 ± 9.47        0.08 ± 0.06
# failing_top_tagger                     9.80 ± 8.42        0.06 ± 0.06
#
#                               Data (MET)                     Total
# sumw                        436545430.00             3862406437.98
# goodvertex                  426625079.00    3862402733.91 ± 293.46
# lumi                        408634159.00    3862402733.91 ± 293.46
# Stitching                   408634159.00  3732925864.99 ± 47482.61
# trigger_tau                 223102707.00     11141775.92 ± 4677.79
# metfilters                  218453560.00     11125459.82 ± 4673.37
# electron_veto               217446970.00      9885208.49 ± 4393.02
# muon_veto                   213771291.00      5527118.97 ± 3430.74
# one_tau                        417511.00         99010.45 ± 351.59
# one_bjet                        27486.00          16993.29 ± 63.47
# delta_phi_jet_met_0.7_True       6750.00           3724.02 ± 27.72
# met_180                          1843.00           1208.83 ± 15.23
# failing_top_tagger               1096.00            614.08 ± 12.42

# %% [markdown]
# # Table report

# %%
table_report, SF = plotter.get_table_report()
table_report
# Out:
# 📋 Available variations: ['cutflow', 'cutflow_ROCHESTER_up', 'cutflow_ROCHESTER_down', 'cutflow_TES_up', 'cutflow_TES_down', 'cutflow_jet_JES_up', 'cutflow_jet_JES_down', 'cutflow_jet_JER_up', 'cutflow_jet_JER_down', 'cutflow_fatjet_JES_up', 'cutflow_fatjet_JES_down', 'cutflow_fatjet_JER_up', 'cutflow_fatjet_JER_down', 'cutflow_met_UNCLUSTERED_up', 'cutflow_met_UNCLUSTERED_down', 'cutflow_raw']
#
# 🔎 Revisando dataset tipo data: MET
# Samples          Events ± stat  Syst up  Syst down  Contribution (%)
# tt               465.95 ± 5.70    50.69      52.28             75.88
# SingleTop         71.46 ± 4.78     9.47       9.48             11.64
# W+jets            64.79 ± 5.23     7.56       7.67             10.55
# DrellYan+jets      9.80 ± 8.42     3.22       2.85              1.60
# VV                 2.03 ± 0.81     0.32       0.32              0.33
# Higgs              0.06 ± 0.06     0.02       0.03              0.01
# Data (MET)             1096.00     0.00       0.00               NaN
# Total bgr       614.08 ± 12.42   572.37     573.74               NaN
# Data/Total bgr            1.78      NaN        NaN               NaN
# Rtt (tt)         2.038 ± 0.034      NaN        NaN               NaN

# %% [markdown]
# # Plot

# %%
variable = "lepton_met_mass" 
binning = [0, 20, 40, 60, 80, 100, 120, 150, 200, 300]

overflow = True
underflow = True

divided_GeV = True
log_scale = True

main_bgr = "tt"
sf_bgr = 1.0

y_axis_range = (0.1, 100)  # cr_d: 50; cr_c: 500; cr_b: 100
ratio_plot_limits = (0.5, 3)

histos,  group = plotter.get_plot_report(distribution = variable, 
                        divided_GeV =divided_GeV, log = log_scale, 
                        overflow = overflow, underflow = underflow,
                        main_bgr = main_bgr , sf_bgr = sf_bgr,
                        y_axis = y_axis_range, ratio_limits = ratio_plot_limits, 
                        binning_hist = binning)

plotter.event_table_by_bin()
# Out:
#  Key available in the pkl files: ['lepton_pt', 'lepton_eta', 'lepton_phi', 'bjet_pt', 'bjet_eta', 'bjet_phi', 'jet_pt', 'jet_eta', 'jet_phi', 'met', 'met_phi', 'recoil_pt', 'recoil_phi', 'lepton_met_mass', 'lepton_met_phi', 'njets_full', 'njets', 'nfatjets', 'nwjets', 'nbjets', 'npvs', 'nmuons', 'nelectrons', 'ntaus', 'ST', 'ST_met', 'ST_full', 'top_mrec', 'genweight', 'top_boost_weight_tau_2017']
# [INFO] Background 'qcd' no está en histograms_dict, se omite.
# [INFO] Se omite 'qcd' porque no está en los pkls
# Plot saved to plots/qcd/cr_d/trigger_weights/2017/lepton_met_mass_2017.pdf
# [INFO] Background 'qcd' no está en histograms_dict, se omite.
# [INFO] Se omite 'qcd' porque no está en los pkls
#                                        $t\bar{t}$  \
# 0-20_         73.80 ± 8.59 (Up: 7.69, Down: 7.86)
# 20-40_        66.42 ± 8.15 (Up: 8.15, Down: 8.37)
# 40-60_        60.84 ± 7.80 (Up: 6.48, Down: 6.47)
# 60-80_        45.52 ± 6.75 (Up: 5.26, Down: 5.37)
# 80-100_       29.35 ± 5.42 (Up: 4.45, Down: 4.60)
# 100-120_      21.63 ± 4.65 (Up: 3.89, Down: 4.17)
# 120-150_      41.07 ± 6.41 (Up: 5.90, Down: 6.33)
# 150-200_      51.91 ± 7.20 (Up: 4.41, Down: 4.39)
# 200-300_      75.41 ± 8.68 (Up: 5.38, Down: 5.50)
# Total     465.95 ± 21.59 (Up: 17.70, Down: 18.18)
#
#                                    Single Top  \
# 0-20_     16.13 ± 4.02 (Up: 1.25, Down: 1.00)
# 20-40_    12.31 ± 3.51 (Up: 2.24, Down: 2.13)
# 40-60_     8.76 ± 2.96 (Up: 1.00, Down: 1.06)
# 60-80_     8.18 ± 2.86 (Up: 0.83, Down: 0.92)
# 80-100_    2.76 ± 1.66 (Up: 0.54, Down: 0.58)
# 100-120_   2.52 ± 1.59 (Up: 0.81, Down: 0.84)
# 120-150_   5.85 ± 2.42 (Up: 1.19, Down: 1.08)
# 150-200_   7.03 ± 2.65 (Up: 0.94, Down: 1.32)
# 200-300_   7.93 ± 2.82 (Up: 1.76, Down: 1.79)
# Total     71.46 ± 8.45 (Up: 3.83, Down: 3.83)
#
#                                     WJetToLNu  \
# 0-20_     16.94 ± 4.12 (Up: 3.72, Down: 3.70)
# 20-40_    14.09 ± 3.75 (Up: 2.72, Down: 2.71)
# 40-60_    12.75 ± 3.57 (Up: 0.97, Down: 1.15)
# 60-80_     5.56 ± 2.36 (Up: 0.99, Down: 0.84)
# 80-100_    4.51 ± 2.12 (Up: 1.53, Down: 1.63)
# 100-120_   1.99 ± 1.41 (Up: 0.10, Down: 0.11)
# 120-150_   3.75 ± 1.94 (Up: 0.64, Down: 0.66)
# 150-200_   1.28 ± 1.13 (Up: 0.55, Down: 0.23)
# 200-300_   3.93 ± 1.98 (Up: 1.24, Down: 1.48)
# Total     64.79 ± 8.05 (Up: 5.27, Down: 5.33)
#
#                                      Diboson  \
# 0-20_     0.43 ± 0.65 (Up: 0.23, Down: 0.23)
# 20-40_    0.42 ± 0.65 (Up: 0.23, Down: 0.23)
# 40-60_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 60-80_    0.12 ± 0.35 (Up: 0.03, Down: 0.04)
# 80-100_   0.00 ± 0.00 (Up: 0.17, Down: 0.17)
# 100-120_  0.35 ± 0.59 (Up: 0.01, Down: 0.01)
# 120-150_  0.23 ± 0.48 (Up: 0.06, Down: 0.09)
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 200-300_  0.48 ± 0.69 (Up: 0.07, Down: 0.08)
# Total     2.03 ± 1.42 (Up: 0.38, Down: 0.39)
#
#                                   DYJetsToLNu  \
# 0-20_      1.91 ± 1.38 (Up: 2.32, Down: 1.51)
# 20-40_     1.62 ± 1.27 (Up: 0.15, Down: 1.62)
# 40-60_     1.86 ± 1.36 (Up: 0.39, Down: 0.39)
# 60-80_     3.04 ± 1.74 (Up: 0.40, Down: 0.40)
# 80-100_   -2.13 ± 1.46 (Up: 2.04, Down: 1.34)
# 100-120_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 120-150_   0.00 ± 0.00 (Up: 0.00, Down: 0.00)
# 150-200_   1.99 ± 1.41 (Up: 2.09, Down: 2.10)
# 200-300_   1.52 ± 1.23 (Up: 0.19, Down: 0.19)
# Total      9.80 ± 3.75 (Up: 3.78, Down: 3.39)
#
#                                        Higgs     Data  \
# 0-20_     0.00 ± 0.00 (Up: 0.02, Down: 0.00)      167
# 20-40_    0.00 ± 0.00 (Up: 0.00, Down: 0.00)      151
# 40-60_    0.05 ± 0.22 (Up: 0.02, Down: 0.03)      131
# 60-80_    0.01 ± 0.09 (Up: 0.00, Down: 0.00)       95
# 80-100_   0.00 ± 0.00 (Up: 0.02, Down: 0.02)       60
# 100-120_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)       61
# 120-150_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      100
# 150-200_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      133
# 200-300_  0.00 ± 0.00 (Up: 0.00, Down: 0.00)      198
# Total     0.06 ± 0.24 (Up: 0.04, Down: 0.04)  1096.00
#
#                                          Total MC  Data / Total MC
# 0-20_       109.20 ± 10.45 (Up: 8.94, Down: 8.87)             1.53
# 20-40_        94.86 ± 9.74 (Up: 8.88, Down: 9.20)             1.59
# 40-60_        84.25 ± 9.18 (Up: 6.64, Down: 6.67)             1.55
# 60-80_        62.44 ± 7.90 (Up: 5.43, Down: 5.53)             1.52
# 80-100_       34.49 ± 6.22 (Up: 5.16, Down: 5.09)             1.74
# 100-120_      26.49 ± 5.15 (Up: 3.98, Down: 4.26)             2.30
# 120-150_      50.89 ± 7.13 (Up: 6.05, Down: 6.46)             1.96
# 150-200_      62.20 ± 7.89 (Up: 5.00, Down: 5.05)             2.14
# 200-300_      89.26 ± 9.45 (Up: 5.80, Down: 5.97)             2.22
# Total     614.08 ± 24.87 (Up: 19.24, Down: 19.63)             1.78
